# %%
import spacy
import numpy as np
import os
import glob
import string
import re
from gensim.models import Word2Vec
from gensim.models import FastText
import pandas as pd

# %%
cd /content/drive/My Drive/Google Colab/RASA/Bangla_wiki_Text
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/Google Colab/RASA/Bangla_wiki_Text'
# /content

# %%
from gensim.models import FastText
fasttext_model = FastText.load('/content/drive/My Drive/Google Colab/RASA/Vector_Model/fasttext_model_bin/fast.bin')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
with open('/content/drive/My Drive/All Spacy/loc3.txt', 'r') as file:
    loc3 = file.read().replace('\n', '')
with open('/content/drive/My Drive/All Spacy/loc2.txt', 'r') as file:
    loc2 = file.read().replace('\n', '')
with open('/content/drive/My Drive/All Spacy/bnwiki-texts-preprocessed.txt', 'r') as file:
    sentence = file.read().replace('\n', '')
#filename = '/content/drive/My Drive/Google Colab/Bangla_Taging/Data/prothomalo_bdnews_920K_shuffle.json' # prothom_alo_data_550+k.json bdnews350+k_1.json
#with open(filename, 'r') as myfile:
    #all_line=myfile.read()

loc3=loc3.replace('উপজেলা',' ')
loc3=loc3.replace('জেলা',' ')
loc3=loc3.replace('সদর ',' ')
loc3=loc3.replace('বিভাগ ',' ')
loc3=loc3.replace('বিভাগের ',' ')
loc3=loc3.replace('উপজেলাসমূহ ',' ')
loc3=loc3.replace('(নোয়াখালী)',' ')
loc3=loc3.replace('(স্বরূপকাঠি)',' ')
loc3=loc3.replace('।',' ')
loc3=loc3.replace(',',' ')
loc2=loc2.replace('\t','')

# %%
patients_df = pd.read_json('/content/drive/My Drive/Google Colab/Bangla_Taging/Data/prothomalo_bdnews_920K_shuffle.json')

# %%
print(loc2)
print(loc3)
# Out:
# জার্মানি,বার্লিন,ইউরো,পোলান্ড,ওয়ারশ ,হাঙ্গেরী,বুদাপেস্ট,রুমানিয়া,বুখারেস্ট,বুলগেরিয়া,সোফিয়া ,স্লোভাকিয়া,ব্লাটিস্লাভা,ক্রোয়েশিয়া,জাগোরেব,স্লোভেনিয়া,লুবজানা,চেক-প্রজাতন্ত্র,প্রাগ,আলবেনিয়া,তিরানা,বসনিয়া হার্জেগোভিনা,সারায়েবো,মন্টিনিগ্রো,পোডগোরিকো,সার্বিয়া,বেলগ্রেড,মেসিডোনিয়া,স্কোপজে,কসোভো,ক্রিস্টিনা,ফ্রান্স,প্যারিস,নরওয়ে,অসলো,সুইডেন,স্টকহোম,ডেনমার্ক,কোপেন হেগেন,ইংল্যান্ড,লন্ডন,রাশিয়া,মস্কো,অস্ট্রিয়া,ভিয়েনা,বেলজিয়াম,ব্রাসেলস,এনডোরা,এনডোরা লা ভিলা,গ্রিস,এথেন্স,ফিনল্যান্ড,হেলসিংকি,সাইপ্রাস,নিকোশিয়া,আইসল্যান্ড,রিকজাভিক,আয়ার‌ল্যান্ড,ডাবলিন,নেদারল্যান্ড,আমস্টারডাম,মালটা,ভালেটা,লুক্সেমবার্গ,লুক্সেমবার্গ,মোনাকো,মোনাকো,পর্তুগাল,লিসবন,সুইজারল্যান্ড,বার্ন,ভ্যাটিকাস সিটি,ইতালি,রোম,বেলারুশ,মিনস্ক,ইউক্রেন,কিয়েভ,এস্তোনিয়া,তাল্লিন,লাটভিয়া,রিগা,আর্মেনিয়া,ইয়েরেভান,জর্জিয়া,তিবলিস,লিথুনিয়া,ভিনিয়াস,মলদোভা,চিসিনিউ,সানমেরিনো,সানমেরিনো,লিচেনস্টেইন,ভাদুজ,স্পেন,মাদ্রিদ,মিশর,কায়রো,সুদান,খার্তুম,লিবিয়া,ত্রিপলি,তিউনিশিয়া,তিউনিশ,আলজেরিয়া,আলজিয়ার্স,দক্ষিণ সুদান,জুরা,ইরিত্রিয়া,আসমেরা,ইথিওপিয়া,আদ্দিস আবাবাবির,জিবুতি,জি
# ...

# %%
def cleaning(data):
  x=[]
  x.append(data)
  for i in range(len(x)):
    x[i] = re.sub(r'\[[0-9]*\]',' ',x[i])
    x[i] = re.sub(r'\[[a-z]*\w+]',' ',x[i])
    regex = re.compile('[a-zA-Z]')
    #First parameter is the replacement, second parameter is your input string \uf06e \uf06c \u200c্যা 	new_string = re.sub("[^a-zA-Z]","", old_string)
    x[i] = regex.sub('', x[i])
    x[i] = re.sub("\uf06e", "", x[i])
    x[i] = re.sub("\uf06c", "", x[i])
    x[i] = re.sub("\u200c্যা", "", x[i])
    x[i] = re.sub("\u200c", "", x[i])
    x[i] = re.sub(r'[@#\$%&\*\(\)\<\>\?\'\‘\’\—\।\!\–\/\".,:;\]\[-]',' ',x[i])
    x[i] = re.sub(r'\d',' ',x[i])
    x[i] = re.sub(r'\s+',' ',x[i])
  return x[0]

# %%
all_line=[]
all_line_update=[]
all_line=patients_df['title']
for i in all_line:
  st=cleaning(i)
  all_line_update.append(st)
all_line_update

# %%
# Out:
# '[\n{"t'

# %%
st=str("সৌদি আরব বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল রাষ্ট্র। বাংলাদেশের সাংবিধানিক নাম গণপ্রজাতন্ত্রী বাংলাদেশ। ভৌগলিকভাবে বাংলাদেশের পশ্চিম, উত্তর ও পূর্ব সীমান্তে ভারত ও দক্ষিণ-পূর্ব সীমান্তে মায়ানমার অবস্থিত। এছাড়াও দক্ষিণ দিকে বঙ্গোপসাগর অবস্থিত। বাংলাদেশের ভূখন্ড ভৌগলিকভাবে একটি উর্বর বদ্বীপের অংশ বিশেষ। বাংলাদেশ ও পার্শ্ববর্তী দেশ ভারতের রাজ্য পশ্চিমবঙ্গ ও ত্রিপুরায় দীর্ঘ সময় ধরে বাঙালি জাতি বাস করছে। এই অঞ্চলের সংখ্যাগরিষ্ট অধিবাসীদের মাতৃভাষা বাংলা ভাষা। প্রাচীন বঙ্গ ভূখন্ডের পূর্বাংশের অংশ পূর্ব বাংলা নামে পরিচিত, যা বর্তমানে বাংলাদেশ নামের দেশ। পৃথিবীতে যে ক'টি রাষ্ট্র জাতিরাষ্ট্র হিসেবে মর্যাদা পায় তার মধ্যে বাংলাদেশ অন্যতম। বাংলাদেশের বর্তমান সীমান্ত তৈরি হয়েছিল ১৯৪৭ খ্রিস্টাব্দে যখন ব্রিটিশ ঔপনিবেশিক শাসনাবসানে, বঙ্গ বেঙ্গল প্রেসিডেন্সি এবং ব্রিটিশ ভারত বিভাগ করা হয়েছিল। বিভাগের পরে বর্তমান বাংলাদেশের অঞ্চল তখন পূর্ব বাংলা নামে পরিচিত, যেটি নবগঠিত দেশ পাকিস্তানের পূর্ব অঞ্চল হিসেবে প্রতিষ্ঠিত করা হয়েছিল। পাকিস্তান অধিরাজ্যে থাকাকালীন পূর্ব বাংলা থেকে পূর্ব পাকিস্তান-এ নামটি পরিবর্তিত করা হয়েছিল। শোষণ, বৈষম্য ও নিপীড়নের বিরুদ্ধে সশস্ত্র সংগ্রামের মধ্য দিয়ে ১৯৭১ খ্রিস্টাব্দে বাংলাদেশ একটি স্বাধীন ও সার্বভৌম দেশ হিসাবে প্রতিষ্ঠিত হয়। স্বাধীনতা পরবর্তী সময়ে দারিদ্র্যপীড়িত বাংলাদেশে বিভিন্ন সময় ঘটেছে দুর্ভিক্ষ ও প্রাকৃতিক দুর্যোগ; এছাড়াও প্রলম্বিত রাজনৈতিক অস্থিতিশীলতা ও পুনঃপৌনিক সামরিক অভ্যুত্থান এদেশের রাজনৈতিক সামগ্রিক স্থিতিশীলতা বারংবার ব্যাহত করেছে। গণসংগ্রামের মধ্য দিয়ে ১৯৯১ খ্রিস্টাব্দে গণতান্ত্রিক শাসনব্যবস্থা পুনঃপ্রতিষ্ঠিত হয়েছে যার ধারাবাহিকতা অদ্যাবধি বর্তমান। সকল প্রতিকূলতা সত্বেও গত দুই দশকে বাংলাদেশের অর্থনীতিক প্রগতি ও সমৃদ্ধি সারা বিশ্বে স্বীকৃতি লাভ করেছে। বিশ্বের সবচেয়ে জনবহুল দেশগুলোর তালিকায় বাংলাদেশের অবস্থান অষ্টম যদিও আয়তনের হিসেবে বাংলাদেশ বিশ্বে ৯৪তম; ফলে বাংলাদেশ বিশ্বের সবচেয়ে ঘনবসতিপূর্ণ দেশগুলোর নবম। মাত্র ৫৬ হাজার বর্গমাইলেরও কম এই ক্ষুদ্রায়তন দেশের বর্তমান জনসংখ্যা ১৫.৫৯ কোটির বেশী অর্থাৎ প্রতি বর্গমাইলে জনবসতি ২৪৯৭ জন। জনসংখ্যার ৯৮ শতাংশ মানুষের মাতৃভাষা বাংলা; শিক্ষার হার ৬৫ শতাংশ। ২০১২-১৩ অর্থবছরে বাংলাদেশের মোট দেশজ উৎপাদনের জিডিপি পরিমাণ ছিল ১১,৯৮,৯২৩ কোটি টাকা চলতি বাজারমূল্যে যা ২০১৩-১৪ অর্থবছরে বৃদ্ধি লাভ করে ১৩,৫০,৯২০ কোটি টাকায় উন্নীত হয়েছে। একই সঙ্গে জনগণের মাথাপিছু বার্ষিক আয় পূর্ববর্তী বৎসরের ১,০৪৪ মার্কিন ডলার থেকে বৃদ্ধি পেয়ে ২০১৩-১৪ অর্থবছরে ১,১৯০ মার্কিন ডলারে উন্নীত হয়েছে মর্মে সরকারী প্রাক্কলন করা হয়েছে, টাকার অঙ্কে যার পরিমাণ ৯২,৫১০ টাকা। দারিদ্রের হার ২৬.২০ শতাংশ, অতিদরিদ্র মানুষের সংখ্যা ১১.৯০ শতাংশ, এবং বার্ষিক দারিদ্র হ্রাসের হার ১.৫ শতাংশ। এই উন্নয়নশীল দেশটি প্রায় দুই দশক যাবৎ বার্ষিক ৫ থেকে ৬.২ শতাংশ হারে অর্থনৈতিক প্রবৃদ্ধির অর্জনপূর্বক পরবর্তী একাদশ অর্থনীতিসমূহের তালিকায় স্থান করে নিয়েছে। রাজধানী ঢাকা ও অন্যান্য শহরের পরিবর্ধন বাংলাদেশের এই উন্নতির চালিকাশক্তিরূপে কাজ করছে। এর কেন্দ্রবিন্দুতে কাজ করেছে একটি উচ্চাকাঙ্ক্ষী মধ্যবিত্ত শ্রেণীর ত্বরিৎ বিকাশ এবং একটি সক্ষম ও সক্রিয় উদ্যোক্তা শ্রেণীর আর্বিভাব। বাংলাদেশের রপ্তানীমুখী পোশাক শিল্প সারা বিশ্বে বিশেষভাবে প্রসিদ্ধ। জনশক্তি রপ্তানীও দেশটির অন্যতম অর্থনৈতিক হাতিয়ার। বাংলাদেশে সংসদীয় গণতান্ত্রিক সরকার ব্যবস্থা প্রচলিত। বাংলাদেশ দক্ষিণ এশীয় আঞ্চলিক সহযোগিতা সংস্থা ও বিমসটেক-এর প্রতিষ্ঠাতা সদস্য। এছাড়া দেশটি জাতিসংঘ, বিশ্ব বাণিজ্য সংস্থা, বিশ্ব শুল্ক সংস্থা, কমনওয়েলথ অফ নেশনস, উন্নয়নশীল ৮টি দেশ, জোট-নিরপেক্ষ আন্দোলন, ওআইসি, ইত্যাদি আন্তর্জাতিক সংঘের সক্রিয় সদস্য।")
data_list=[]
small_data=[]
s=str("")
for i in st:
  s=s+i
  if(i=='।'):
    data_list.append(s)
    #print('"'+s+'"')
    s=""
for i in data_list:
  small_data.append(cleaning(i))
small_data

# %%
all_line

# %%
#loc2=cleaning(loc2)
#loc3=cleaning(loc3)
sentence=cleaning(sentence)
all_line=cleaning(all_line)

# %%
loc2=loc2.split(',')
loc3=loc3.split()

# %%
location="সৌদি আরব,সৌদি,আরব,বাংলাদেশ,কোরিয়া,এশিয়া,আমেরিকা,বাংলাদেশ,ঢাকা,চট্টগ্রাম,খুলনা,নারায়ণগঞ্জ,সিলেট,গাজীপুর,রাজশাহী,বগুড়া,বরিশাল,কুমিল্লা,পাবনা,ময়মনসিংহ,রংপুর,খুলনা,বাগেরহাটের,সাতক্ষীরা,যশোর,মেহেরপুর,কুষ্টিয়া,ঝিনাইদহ,চুয়াডাঙ্গা,নড়াইল,মাগুরা,চট্টগ্রাম,"
l1 = "চট্টগ্রাম,চাঁদপুর,ফেনী,নোয়াখালী,রাঙ্গামাটি,লক্ষ্মীপুর,খাগড়াছড়ি,কক্সবাজার,কুমিল্লা,ব্রাহ্মণবাড়িয়া,ঢাকা,ঢাকা,ফরিদপুর,গাজীপুর,গোপালগঞ্জ,কিশোরগঞ্জ,মাদারিপুর,মানিকগঞ্জ,মুন্সীগঞ্জ,নারায়ণগঞ্জ,নরসিংদী,রাজবাড়ী,শরীয়তপুর,"
l2 = "টাঙ্গাইল,বরিশাল,বরিশাল,পটুয়াখালী,ভোলা,বরগুনা,পিরোজপুর,ময়মনসিংহ,জামালপুর,নেত্রকোনা,ময়মনসিংহ,শেরপুর,রংপুর,কুড়িগ্রাম,গাইবান্ধা,ঠাকুরগাঁও,দিনাজপুর,নীলফামারী,পঞ্চগড়,রংপুর,লালমনিরহাট,রাজশাহী,নওগাঁ,"
l3 = "চাঁপাইনবাবগঞ্জ,পাবনা,বগুড়া,রাজশাহী,সিরাজগঞ্জ,সিলেট,হবিগঞ্জ,মৌলভীবাজার,সুনামগঞ্জ,বান্দরবান,ব্রাক্ষ্মণবাড়িয়া,চাঁদপুর,চট্রগ্রাম,কুমিল্লা,কক্সবাজার,ফেনী,খাগড়াছড়ি,লক্ষ্মীপুর,নোয়াখালী,রাঙ্গামাটি,বগুড়া,চাঁপাই নবাবগঞ্জ,"
l4 = "জয়পুরহাট,পাবনা,নওগাঁ,নাটোর,রাজশাহী,সিরাজগঞ্জ,বাগেরহাট,চুয়াডাঙ্গা,যশোর,ঝিনাইদহ,খুলনা,কুষ্টিয়া,মাগুরা,মেহেরপুর,নড়াইল,সাতক্ষীরা,বরগুনা,বরিশাল,ভোলা,ঝালকাঠী,পটুয়াখালী,পিরোজপুর,হবিগঞ্জ,মৌলভীবাজার,"
l5 = "সুনামগঞ্জ,সিলেট,ঢাকা,ফরিদপুর,গাজীপুর,গোপালগঞ্জ,জামালপুর,কিশোরগঞ্জ,মাদারীপুর,মানিকগঞ্জ,মুন্সীগঞ্জ,ময়মনসিংহ,নারায়নগঞ্জ,নরসিংদী,নেত্রকোণা,রাজবাড়ী,শরিয়তপুর,শেরপুর,টাঙ্গাইল,রংপুর,দিনাজপুর,গাইবান্ধা,কুড়িগ্রাম,লালমনিরহাট,নীলফামারী,পঞ্চগড়,রংপুর,ঠাকুরগাঁও,"
l6 = "ভারত,নয়াদিল্লী,পাকিস্তান,ইসলামাবাদ,শ্রীলংকা,কলম্বো,নেপাল,কাঠমুন্ডু,ভুটান,থিম্পু,মালদ্বীপ,মালে,মায়ানমার,নাইপিদো,আফগানিস্তান,কাবুল,ইন্দোনেশিয়া,জাকার্তা,মালয়েশিয়া,মালেশিয়া,কুয়ালালামপুর,সিঙ্গাপুর,সিঙ্গাপুর সিটি,থাইল্যান্ড,ব্যাংকক,ভিয়েতনাম,হ্যানয়,লাওস,ভিয়েন তিয়েন,কম্বোডিয়া,নমপেন,ব্রুনাই,বন্দর সেরী,পূর্ব তিমুর,দিলি,ফিলিপাইন,ম্যানিলা,কাজাকিস্তান,আলমাআতা,কিরগিজিস্তান,বিশবেক,তাজিকিস্তান,দুশানবে,তুর্কমেনিস্তান,আশাখাবাদ,উজবেকিস্তান,তাশখন্দ,আজারবাইজানবাকু,চীন,বেইজিংজাপান,টোকিও,উত্তর কোরিয়া,পিয়ংইয়ং,দক্ষিণ কোরিয়া,সিউল,তাইওয়ান,তাইপে,মঙ্গোলিয়া,উলান বাটর,বাহরাইন,মানামা,ইরান,তেহরান,ইরাক,বাগদাদ,ইসরাইল,জেরুজালেম,জর্ডান,আম্মান,কুয়েত,কুয়েত সিটি,লেবানন,বৈরুত,ওমান,মাসকট,কাতার,দোহা,সৌদি আরব,রিয়াদ,সিরিয়া,দামেস্ক,ইয়েমেন,সানা,সংযুক্ত আরব আমিরাত,তুরস্ক,আঙ্কারা,ফিলিস্তিন,রামাল্লা"

# %%
location = location+l1+l2+l3+l4+l5+l6
location_list = location.split(',')
location_list=location_list+loc2+loc3
print(location_list)
# Out:
# ['সৌদি আরব', 'সৌদি', 'আরব', 'বাংলাদেশ', 'কোরিয়া', 'এশিয়া', 'আমেরিকা', 'বাংলাদেশ', 'ঢাকা', 'চট্টগ্রাম', 'খুলনা', 'নারায়ণগঞ্জ', 'সিলেট', 'গাজীপুর', 'রাজশাহী', 'বগুড়া', 'বরিশাল', 'কুমিল্লা', 'পাবনা', 'ময়মনসিংহ', 'রংপুর', 'খুলনা', 'বাগেরহাটের', 'সাতক্ষীরা', 'যশোর', 'মেহেরপুর', 'কুষ্টিয়া', 'ঝিনাইদহ', 'চুয়াডাঙ্গা', 'নড়াইল', 'মাগুরা', 'চট্টগ্রাম', 'চট্টগ্রাম', 'চাঁদপুর', 'ফেনী', 'নোয়াখালী', 'রাঙ্গামাটি', 'লক্ষ্মীপুর', 'খাগড়াছড়ি', 'কক্সবাজার', 'কুমিল্লা', 'ব্রাহ্মণবাড়িয়া', 'ঢাকা', 'ঢাকা', 'ফরিদপুর', 'গাজীপুর', 'গোপালগঞ্জ', 'কিশোরগঞ্জ', 'মাদারিপুর', 'মানিকগঞ্জ', 'মুন্সীগঞ্জ', 'নারায়ণগঞ্জ', 'নরসিংদী', 'রাজবাড়ী', 'শরীয়তপুর', 'টাঙ্গাইল', 'বরিশাল', 'বরিশাল', 'পটুয়াখালী', 'ভোলা', 'বরগুনা', 'পিরোজপুর', 'ময়মনসিংহ', 'জামালপুর', 'নেত্রকোনা', 'ময়মনসিংহ', 'শেরপুর', 'রংপুর', 'কুড়িগ্রাম', 'গাইবান্ধা', 'ঠাকুরগাঁও', 'দিনাজপুর', 'নীলফামারী', 'পঞ্চগড়', 'রংপুর', 'লালমনিরহাট', 'রাজশাহী', 'নওগাঁ', 'চাঁপাইনবাবগঞ্জ', 'পাবনা', 'বগুড়া', 'রাজশাহী', 'সিরাজগঞ্জ', 'সিলেট', 'হবিগঞ্জ', 'মৌলভীবাজার', 
# ...

# %%
print(loc2)
print(loc3)
# Out:
# ['জার্মানি', 'বার্লিন', 'ইউরো', 'পোলান্ড', 'ওয়ারশ ', 'হাঙ্গেরী', 'বুদাপেস্ট', 'রুমানিয়া', 'বুখারেস্ট', 'বুলগেরিয়া', 'সোফিয়া ', 'স্লোভাকিয়া', 'ব্লাটিস্লাভা', 'ক্রোয়েশিয়া', 'জাগোরেব', 'স্লোভেনিয়া', 'লুবজানা', 'চেক-প্রজাতন্ত্র', 'প্রাগ', 'আলবেনিয়া', 'তিরানা', 'বসনিয়া হার্জেগোভিনা', 'সারায়েবো', 'মন্টিনিগ্রো', 'পোডগোরিকো', 'সার্বিয়া', 'বেলগ্রেড', 'মেসিডোনিয়া', 'স্কোপজে', 'কসোভো', 'ক্রিস্টিনা', 'ফ্রান্স', 'প্যারিস', 'নরওয়ে', 'অসলো', 'সুইডেন', 'স্টকহোম', 'ডেনমার্ক', 'কোপেন হেগেন', 'ইংল্যান্ড', 'লন্ডন', 'রাশিয়া', 'মস্কো', 'অস্ট্রিয়া', 'ভিয়েনা', 'বেলজিয়াম', 'ব্রাসেলস', 'এনডোরা', 'এনডোরা লা ভিলা', 'গ্রিস', 'এথেন্স', 'ফিনল্যান্ড', 'হেলসিংকি', 'সাইপ্রাস', 'নিকোশিয়া', 'আইসল্যান্ড', 'রিকজাভিক', 'আয়ার\u200cল্যান্ড', 'ডাবলিন', 'নেদারল্যান্ড', 'আমস্টারডাম', 'মালটা', 'ভালেটা', 'লুক্সেমবার্গ', 'লুক্সেমবার্গ', 'মোনাকো', 'মোনাকো', 'পর্তুগাল', 'লিসবন', 'সুইজারল্যান্ড', 'বার্ন', 'ভ্যাটিকাস সিটি', 'ইতালি', 'রোম', 'বেলারুশ', 'মিনস্ক', 'ইউক্রেন', 'কিয়েভ', 'এস্তোনিয়া', 'তাল্লিন', 'লাটভিয়া', 'রিগা', 'আর্মেনিয়া'
# ...

# %%
multi_level=[]
single_level=[]
for i in location_list:
  temp=i.split()
  if len(temp)>1:
    multi_level.append(i)
  else:
    single_level.append(i)

# %%
multi_level=np.unique(multi_level)
single_level=np.unique(single_level)
print(len(multi_level))
print(len(single_level))
# Out:
# 55
# 862

# %%
all_list

# %%
final_sentence=[]
all_list=np.unique(location_list)
for i in all_line_update:
  #print(i)
  temp=str(i)
  for j in all_list:
    #print(j)
    tm=str(j)
    if tm in temp and tm != '':
      #print(j, ' ', i)
      final_sentence.append(i)
      break
print(len(final_sentence))
# Out:
# 241768

# %%
import csv
with open('/content/drive/My Drive/All Spacy/final_location_sentence.csv', 'w', newline='') as myfile:
  wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
  wr.writerow(final_sentence)

# %%
df=pd.read_csv('/content/drive/My Drive/All Spacy/final_location_sentence.csv')
#df.head(10)

# %%
k = ['আজি উত্তর কোরিয়ার আজ']
st = k[0]
start = st.index('আজ')
end = len('আজ')
print(start,' ',start+end)
# Out:
# 0   2

# %%
entity_list=['বাংলাদেশ', 'এশিয়া']
entity_list2=['সৌদি আরব', 'দক্ষিণ এশিয়া','বাংলাদেশ মেডিকেল কলেজ']
sentence=['সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত','বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত']
for i in sentence:
  mp={}
  for j in range(0,1001):
    mp[j]=0
  for j in entity_list2:
    try:
      st=i
      s=j
      print(i,' ',j)
      start = st.index(j)
      end = len(j)
      for k in range(end,len(i)):
        if i[k] == ' ' or k == len(i)-1:
          break
        s=s+i[k]
      end = len(s)
      if mp[start] == 0 and mp[end] == 0:
        print(s,' ',start,' ',end)
      for k in range(start,end):
        mp[k]=1
    except:
      print('not match')
      
  for j in entity_list:
    print()
    try:
      print(i,' ',j)
      st=i
      s=j
      start = st.index(j)
      end = len(j)
      for k in range(end,len(i)):
        if i[k] == ' ' or k == len(i)-1:
          break
        s=s+i[k]
      end = len(s)
      if mp[start] == 0 and mp[end] == 0:
        print(s,' ',start,' ',end)
      for k in range(start,end):
        mp[k]=1
    except:
      print('not match')
# Out:
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত   সৌদি আরব
# সৌদি আরব   0   8
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত   দক্ষিণ এশিয়া
# দক্ষিণ এশিয়ায়ার   26   15
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত   বাংলাদেশ মেডিকেল কলেজ
# not match
#
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত   বাংলাদেশ
# not match
#
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত   এশিয়া
# এশিয়াআরব   9   8
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত   সৌদি আরব
# not match
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত   দক্ষিণ এশিয়া
# not match
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত   বাংলাদেশ মেডিকেল কলেজ
# বাংলাদেশ মেডিকেল কলেজতিষ্ঠান   29   28
#
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত   বাংলাদেশ
# বাংলাদেশের   0   10
#
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত   এশিয়া
# ...

# %%
single_level_add=[]
multi_level_add=[]
non_entity=[]

# %%
entity_list=['বাংলাদেশ', 'এশিয়া']
entity_list2=['সৌদি আরব', 'দক্ষিণ এশিয়া','বাংলাদেশ মেডিকেল কলেজ']
sentence=['সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত','বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত']
for l in sentence:
  stri=l
  print()
  mp={}
  for i in range(0,1001):
    mp[i]=0
  for i in entity_list2:
      pos=[]
      f=0
      pos.append(0)
      s=stri[0]
      for j in range(len(stri)):
        if stri[j] == ' ':
          pos.append(j)
      for j in pos:
        for k in range(j+1,len(stri)):
          #print(s)
          s=s+stri[k]
          if s == i:
            #multi_level_add.append(s)
            ind=0
            for comma in range(k+1,len(stri)):
              if stri[comma] == ' ':
                ind=comma
                break
              else: s=s+stri[comma]
            #loc_list.append(s)
            #print(s,' ',i)
           # multi_level_add.append(s)
            if ind == 0: ind=len(stri)
            temp_st=str("")
            if j==0 and stri[0]!=' ':
              #for rep in range(len(stri)):
                #if rep <j or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              if mp[j] == 0 and mp[ind] == 0:
                print(s,' ',j,' ',ind)
              for mapping in range(j,ind+1):
                mp[mapping]=1
            else:
              #for rep in range(len(stri)):
                #if rep <j+1 or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              if mp[j+1] == 0 and mp[ind] == 0:
                print(s,' ',j+1,' ',ind)
              for mapping in range(j+1,ind+1):
                mp[mapping]=1
            f=1
            print(stri)
            break
          elif len(s) == len(i):
            s=""
            break
        if f == 1:
          s=""
          f=0
  for i in entity_list:
      pos=[]
      f=0
      pos.append(0)
      s=stri[0]
      for j in range(len(stri)):
        if stri[j] == ' ':
          pos.append(j)
      for j in pos:
        for k in range(j+1,len(stri)):
          #print(s)
          s=s+stri[k]
          if s == i:
            #single_level_add.append(s)
            ind=0
            for comma in range(k+1,len(stri)):
              if stri[comma] == ' ':
                ind=comma
                break
              else: s=s+stri[comma]
            #loc_list.append(s)
            #print(s,' ',i)
            #single_level_add.append(s)
            if ind == 0: ind=len(stri)
            temp_st=str("")
            if j==0 and stri[0]!=' ':
              #for rep in range(len(stri)):
                #if rep <j or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              if mp[j] == 0 and mp[ind] == 0:
                print(s,' ',j,' ',ind)
              for mapping in range(j,ind+1):
                mp[mapping]=1
            else:
              #for rep in range(len(stri)):
                #if rep <j+1 or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              if mp[j+1] == 0 and mp[ind] == 0:
                print(s,' ',j+1,' ',ind)
              for mapping in range(j+1,ind+1):
                mp[mapping]=1
            f=1
            print(stri)
            break
          elif len(s) == len(i):
            s=""
            break
        if f == 1:
          s=""
          f=0
# Out:
# সৌদি আরব   0   8
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত
# দক্ষিণ এশিয়ার   26   39
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত
# এশিয়ার   9   15
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত
# সৌদি আরব এশিয়ার মধ্যে এবং দক্ষিণ এশিয়ার পাশে অবস্থিত
#
# বাংলাদেশ মেডিকেল কলেজ   29   50
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত
# বাংলাদেশের   0   10
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত
# বাংলাদেশের   51   61
# বাংলাদেশের অন্যতম প্রতিষ্ঠান বাংলাদেশ মেডিকেল কলেজ বাংলাদেশের উত্তরে অবস্থিত

# %%
def multi(stri):
  for i in multi_level:
      pos=[]
      f=0
      pos.append(0)
      s=stri[0]
      for j in range(len(stri)):
        if stri[j] == ' ':
          pos.append(j)
      for j in pos:
        for k in range(j+1,len(stri)):
          #print(s)
          s=s+stri[k]
          if s == i:
            multi_level_add.append(s)
            ind=0
            for comma in range(k+1,len(stri)):
              if stri[comma] == ' ':
                ind=comma
                break
              else: s=s+stri[comma]
            #loc_list.append(s)
            print(s,' ',i)
            multi_level_add.append(s)
            if ind == 0: ind=len(stri)
            temp_st=str("")
            if j==0 and stri[0]!=' ':
              #for rep in range(len(stri)):
                #if rep <j or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              print(s,' ',j,' ',ind)
            else:
              #for rep in range(len(stri)):
                #if rep <j+1 or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              print(s,' ',j+1,' ',ind)
            f=1
            print(stri)
            break
          elif len(s) == len(i):
            s=""
            break
        if f == 1:
          s=""
          f=0
def single(stri):
  for i in single_level:
      pos=[]
      f=0
      pos.append(0)
      s=stri[0]
      for j in range(len(stri)):
        if stri[j] == ' ':
          pos.append(j)
      for j in pos:
        for k in range(j+1,len(stri)):
          #print(s)
          s=s+stri[k]
          if s == i:
            single_level_add.append(s)
            ind=0
            for comma in range(k+1,len(stri)):
              if stri[comma] == ' ':
                ind=comma
                break
              else: s=s+stri[comma]
            #loc_list.append(s)
            #print(s,' ',i)
            single_level_add.append(s)
            if ind == 0: ind=len(stri)
            temp_st=str("")
            if j==0 and stri[0]!=' ':
              #for rep in range(len(stri)):
                #if rep <j or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              print(s,' ',j,' ',ind)
            else:
              #for rep in range(len(stri)):
                #if rep <j+1 or rep>=ind:
                  #temp_st=temp_st+stri[rep]
              #stri=temp_st
              print(s,' ',j+1,' ',ind)
            f=1
            #print(stri)
            break
          elif len(s) == len(i):
            s=""
            break
        if f == 1:
          s=""
          f=0

# %%
temp = ['বাংলাদেশ','দক্ষিণ','পাকিস্তানের','উত্তর কোরিয়া','কুয়েত সিটির','ফেনী জেলা সদর','ঢাকা জেলা সদর']
loc_list =  ['বাংলাদেশ','দক্ষিণ','পাকিস্তানের','ফেনী','ঢাকা','ফেনী জেলা সদর','ঢাকা জেলা সদর']
stri=str('সৌদি আরব বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল রাষ্ট্র')
#alll=[' আমি লক্ষ্মীপুরে থাকি কিন্তু আমি ঢাকার লোক ও ফেনী জেলা সদর',' আমি লক্ষ্মীপুরে থাকি কিন্তু আমি ঢাকা জেলা সদর লোক ও ফেনী জেলা সদর']
#stri=str(' dhaka live in dhaka bangladesh but my hometown in feni town.')
#temp=['bangladesh','dhaka','feni']
#বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল রাষ্ট্র
for l in small_data:
#for l in range(0,1):
  stri=l
  multi(stri)
  single(stri)
  temp_line=stri.split()
  for i in temp_line:
    if (i not in single_level_add) and (i not in multi_level_add):
      non_entity.append(i)
print(multi_level_add)
print(single_level_add)
print(non_entity)
# Out:
# সৌদি আরব   সৌদি আরব
# সৌদি আরব   0   9
# সৌদি আরব বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল রাষ্ট্র
# আরব   6   9
# দক্ষিণ   19   25
# বাংলাদেশ   10   18
# সৌদি   0   5
# বাংলাদেশের   1   11
# বাংলাদেশ   42   50
# উত্তর   30   35
# দক্ষিণ   60   66
# বাংলাদেশের   12   22
# ভারত   53   57
# দক্ষিণ   9   15
# বাংলাদেশের   1   11
# বাংলাদেশ   1   9
# ভারতের   29   35
# বাংলাদেশ   74   82
# বাংলাদেশ   68   76
# বাংলাদেশের   1   11
# ভারত   124   128
# পাকিস্তানের   82   93
# বাংলাদেশের   21   31
# পাকিস্তান   1   10
# পাকিস্তান   54   63
# বাংলাদেশ   76   84
# বাংলাদেশে   41   50
# বাংলাদেশের   35   45
# বাংলাদেশের   42   52
# বাংলাদেশ   87   95
# বাংলাদেশ   110   118
# বাংলাদেশের   10   20
# ঢাকা   9   13
# বাংলাদেশের   40   50
# বাংলাদেশের   1   11
# হাতিয়ার   42   50
# বাংলাদেশে   1   10
# দক্ষিণ   10   16
# বাংলাদেশ   1   9
# ['সৌদি আরব', 'সৌদি আরব']
# ...

# %%
single_level_add1=np.unique(single_level_add+single_level)
multi_level_add1=np.unique(multi_level_add+multi_level)
non_entity1=np.unique(non_entity)
print(single_level_add1)
print(multi_level_add1)
print(non_entity1)

# %%
def add_char(single_level_add):
  single_level_add_up=[]
  for i in single_level_add:
    #i='ঢাকা'
    tempA=i+'ে'
    tempB=i+'তে'
    tempC=i+'য়'
    tempD=i+'র'
    tempE=i+'া'
    tempH=i+'ার'
    tempF=i+'ের'
    tempG=i+'েতে'
    single_level_add_up.append(i)
    single_level_add_up.append(tempA)
    single_level_add_up.append(tempB)
    single_level_add_up.append(tempC)
    single_level_add_up.append(tempD)
    single_level_add_up.append(tempE)
    single_level_add_up.append(tempF)
    single_level_add_up.append(tempG)
    single_level_add_up.append(tempH)
    #print(tempA,' ',tempB,' ',tempC,' ',tempD,' ',tempE,' ',tempF,' ',tempG,' ',tempH)
  # print(single_level_add_up)
  return single_level_add_up

# %%
single_level_add=add_char(single_level_add)
multi_level_add=add_char(multi_level_add)
non_entity=add_char(non_entity)

# %%
train_data=[]
aa='("অব", {"entities": [(0, 2,"LOC"),]}),'
train_data.append(aa)
print(train_data,' ',type(train_data))
# Out:
# ['("অব", {"entities": [(0, 2,"LOC"),]}),']   <class 'list'>

# %%
print ("List in proper method", '%s' % ', '.join(map(str, train_data)))
# Out:
# List in proper method ("অব", {"entities": [(0, 2,"LOC"),]}),

# %%
import json
json_string = json.dumps(train_data, ensure_ascii=False, encoding='utf8')
print(json_string)

# %%
for i in single_level_add:
  aa='('+'"'+i+'"'+', {'+'"entities": '+'[('+str(0)+', '+str(len(i))+',"LOC"'+'),]}),'
  train_data.append(aa)
  print(aa)

# %%
for i in multi_level_add:
  aa='('+'"'+i+'"'+', {'+'"entities": '+'[('+str(0)+', '+str(len(i))+',"LOC"'+'),]}),'
  train_data.append(aa)
  print(aa)

# %%
for i in non_entity:
  aa='('+'"'+i+'"'+', {'+'"entities": '+'[('+str(0)+', '+str(len(i))+',"NE"'+'),]}),'
  train_data.append(aa)
  print(aa)

# %%
TRAIN_DATA=[("অটোয়া", {"entities": [(0, 5,"LOC"),]}),
("অব", {"entities": [(0, 2,"LOC"),]}),
("অবস্থান", {"entities": [(0, 7,"LOC"),]}),
("অবস্থিত", {"entities": [(0, 7,"LOC"),]}),
("অভয়নগর", {"entities": [(0, 7,"LOC"),]}),
("অষ্টগ্রাম", {"entities": [(0, 9,"LOC"),]}),
("অসলো", {"entities": [(0, 4,"LOC"),]}),
("অস্ট্রিয়া", {"entities": [(0, 9,"LOC"),]}),
("অস্ট্রেলিয়া", {"entities": [(0, 11,"LOC"),]}),
("অ্যাঙ্গুইলা", {"entities": [(0, 11,"LOC"),]}),
("আইভোরিকোস্ট", {"entities": [(0, 11,"LOC"),]}),
("আইসল্যান্ড", {"entities": [(0, 10,"LOC"),]}),
("আইয়ুননং", {"entities": [(0, 7,"LOC"),]}),
("আক্কেলপুর", {"entities": [(0, 9,"LOC"),]}),
("আক্রা", {"entities": [(0, 5,"LOC"),]}),
("আখাউড়া", {"entities": [(0, 7,"LOC"),]}),
("আগৈলঝাড়া", {"entities": [(0, 9,"LOC"),]}),
("আঙ্কারা", {"entities": [(0, 7,"LOC"),]}),
("আজমিরীগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("আজারবাইজানবাকু", {"entities": [(0, 14,"LOC"),]}),
("আটঘরিয়া", {"entities": [(0, 8,"LOC"),]}),
("আটপাড়া", {"entities": [(0, 7,"LOC"),]}),
("আটোয়ারী", {"entities": [(0, 8,"LOC"),]}),
("আড়াইহাজার", {"entities": [(0, 10,"LOC"),]}),
("আত্রাই", {"entities": [(0, 6,"LOC"),]}),
("আদমদিঘী", {"entities": [(0, 7,"LOC"),]}),
("আদিতমারী", {"entities": [(0, 8,"LOC"),]}),
("আদ্দিস", {"entities": [(0, 6,"LOC"),]}),
("আনোয়ারা", {"entities": [(0, 8,"LOC"),]}),
("আন্টা", {"entities": [(0, 5,"LOC"),]}),
("আপিয়া", {"entities": [(0, 5,"LOC"),]}),
("আফগানিস্তান", {"entities": [(0, 11,"LOC"),]}),
("আফ্রিকা", {"entities": [(0, 7,"LOC"),]}),
("আফ্রিকান", {"entities": [(0, 8,"LOC"),]}),
("আবাবা", {"entities": [(0, 5,"LOC"),]}),
("আবিদজান", {"entities": [(0, 7,"LOC"),]}),
("আবুজার", {"entities": [(0, 6,"LOC"),]}),
("আমতলী", {"entities": [(0, 5,"LOC"),]}),
("আমস্টারডাম", {"entities": [(0, 10,"LOC"),]}),
("আমেরিকা", {"entities": [(0, 7,"LOC"),]}),
("আম্মান", {"entities": [(0, 6,"LOC"),]}),
("আরব", {"entities": [(0, 3,"LOC"),]}),
("আর্জেন্টিনা", {"entities": [(0, 11,"LOC"),]}),
("আর্মেনিয়া", {"entities": [(0, 9,"LOC"),]}),
("আল", {"entities": [(0, 2,"LOC"),]}),
("আলজিয়ার্স", {"entities": [(0, 9,"LOC"),]}),
("আলজেরিয়া", {"entities": [(0, 8,"LOC"),]}),
("আলফাডাঙা", {"entities": [(0, 8,"LOC"),]}),
("আলবেনিয়া", {"entities": [(0, 8,"LOC"),]}),
("আলমডাঙ্গা", {"entities": [(0, 9,"LOC"),]}),
("আলমাআতা", {"entities": [(0, 7,"LOC"),]}),
("আলিকদম", {"entities": [(0, 6,"LOC"),]}),
("আশাখাবাদ", {"entities": [(0, 8,"LOC"),]}),
("আশাশুনি", {"entities": [(0, 7,"LOC"),]}),
("আশুগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("আসমেরা", {"entities": [(0, 6,"LOC"),]}),
("আসুনসিওন", {"entities": [(0, 8,"LOC"),]}),
("আয়ারল্যান্ড", {"entities": [(0, 11,"LOC"),]}),
("আয়ার্স", {"entities": [(0, 6,"LOC"),]}),
("ইংল্যান্ড", {"entities": [(0, 9,"LOC"),]}),
("ইউক্রেন", {"entities": [(0, 7,"LOC"),]}),
("ইউরোপোলান্ড", {"entities": [(0, 11,"LOC"),]}),
("ইকুটোরিয়াল", {"entities": [(0, 10,"LOC"),]}),
("ইকুয়েডর", {"entities": [(0, 7,"LOC"),]}),
("ইটনা", {"entities": [(0, 4,"LOC"),]}),
("ইতালি", {"entities": [(0, 5,"LOC"),]}),
("ইথিওপিয়া", {"entities": [(0, 8,"LOC"),]}),
("ইন্দোনেশিয়া", {"entities": [(0, 11,"LOC"),]}),
("ইরাক", {"entities": [(0, 4,"LOC"),]}),
("ইরান", {"entities": [(0, 4,"LOC"),]}),
("ইরিত্রিয়া", {"entities": [(0, 9,"LOC"),]}),
("ইসরাইল", {"entities": [(0, 6,"LOC"),]}),
("ইসলামপুর", {"entities": [(0, 8,"LOC"),]}),
("ইসলামাবাদ", {"entities": [(0, 9,"LOC"),]}),
("ইয়াউন্ডি", {"entities": [(0, 8,"LOC"),]}),
("ইয়েমেন", {"entities": [(0, 6,"LOC"),]}),
("ইয়েরেন", {"entities": [(0, 6,"LOC"),]}),
("ইয়েরেভান", {"entities": [(0, 8,"LOC"),]}),
("ঈশ্বরগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("ঈশ্বরদী", {"entities": [(0, 7,"LOC"),]}),
("উইন্ডহোক", {"entities": [(0, 8,"LOC"),]}),
("উখিয়া", {"entities": [(0, 6,"LOC"),]}),
("উগান্ডা", {"entities": [(0, 7,"LOC"),]}),
("উজবেকিস্তান", {"entities": [(0, 11,"LOC"),]}),
("উজিরপুর", {"entities": [(0, 7,"LOC"),]}),
("উত্তর", {"entities": [(0, 5,"LOC"),]}),
("উরুগুয়ে", {"entities": [(0, 7,"LOC"),]}),
("উলিপুর", {"entities": [(0, 6,"LOC"),]}),
("উল্লাপাড়া", {"entities": [(0, 10,"LOC"),]}),
("উয়াগাড়ায়াগা", {"entities": [(0, 11,"LOC"),]}),
("এঙ্গোলা", {"entities": [(0, 7,"LOC"),]}),
("এজামেনা", {"entities": [(0, 7,"LOC"),]}),
("এথেন্স", {"entities": [(0, 6,"LOC"),]}),
("এনডোরা", {"entities": [(0, 6,"LOC"),]}),
("এন্টিগুয়া", {"entities": [(0, 9,"LOC"),]}),
("এন্ড", {"entities": [(0, 4,"LOC"),]}),
("এল", {"entities": [(0, 2,"LOC"),]}),
("এশিয়া", {"entities": [(0, 5,"LOC"),]}),
("এস্তোনিয়া", {"entities": [(0, 9,"LOC"),]}),
("ও", {"entities": [(0, 1,"LOC"),]}),
("ওমান", {"entities": [(0, 4,"LOC"),]}),
("ওসমানীনগর", {"entities": [(0, 9,"LOC"),]}),
("ওয়ারশ", {"entities": [(0, 5,"LOC"),]}),
("ওয়াশিংটন", {"entities": [(0, 8,"LOC"),]}),
("ওয়েলিংটন", {"entities": [(0, 8,"LOC"),]}),
("কক্সবাজার", {"entities": [(0, 9,"LOC"),]}),
("কঙ্গো", {"entities": [(0, 5,"LOC"),]}),
("কচুয়া", {"entities": [(0, 6,"LOC"),]}),
("কটিয়াদি", {"entities": [(0, 8,"LOC"),]}),
("কবিরহাট", {"entities": [(0, 7,"LOC"),]}),
("কমরোস", {"entities": [(0, 5,"LOC"),]}),
("কমলগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("কমলনগর", {"entities": [(0, 6,"LOC"),]}),
("কম্বোডিয়া", {"entities": [(0, 9,"LOC"),]}),
("কয়রা", {"entities": [(0, 5,"LOC"),]}),
("করিমগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("কর্ণফুলি", {"entities": [(0, 8,"LOC"),]}),
("কলমাকান্দা", {"entities": [(0, 10,"LOC"),]}),
("কলম্বিয়া", {"entities": [(0, 8,"LOC"),]}),
("কলম্বো", {"entities": [(0, 6,"LOC"),]}),
("কলাপাড়া", {"entities": [(0, 8,"LOC"),]}),
("কলারোয়া", {"entities": [(0, 8,"LOC"),]}),
("কসবা", {"entities": [(0, 4,"LOC"),]}),
("কসোভো", {"entities": [(0, 5,"LOC"),]}),
("কাঁঠালিয়া", {"entities": [(0, 10,"LOC"),]}),
("কাউখালী", {"entities": [(0, 7,"LOC"),]}),
("কাউনিয়া", {"entities": [(0, 8,"LOC"),]}),
("কাজাকিস্তান", {"entities": [(0, 11,"LOC"),]}),
("কাজীপুর", {"entities": [(0, 7,"LOC"),]}),
("কাঠমুন্ডু", {"entities": [(0, 9,"LOC"),]}),
("কাতার", {"entities": [(0, 5,"LOC"),]}),
("কানাইঘাট", {"entities": [(0, 8,"LOC"),]}),
("কানাডা", {"entities": [(0, 6,"LOC"),]}),
("কাপাসিয়া", {"entities": [(0, 9,"LOC"),]}),
("কাপ্তাই", {"entities": [(0, 7,"LOC"),]}),
("কাবুল", {"entities": [(0, 5,"LOC"),]}),
("কামপালা", {"entities": [(0, 7,"LOC"),]}),
("কামারখন্দ", {"entities": [(0, 9,"LOC"),]}),
("কারাকাস", {"entities": [(0, 7,"LOC"),]}),
("কারাগাডোস", {"entities": [(0, 9,"LOC"),]}),
("কারাজোস", {"entities": [(0, 7,"LOC"),]}),
("কালকিনী", {"entities": [(0, 7,"LOC"),]}),
("কালাই", {"entities": [(0, 5,"LOC"),]}),
("কালিয়া", {"entities": [(0, 7,"LOC"),]}),
("কালিয়াকৈর", {"entities": [(0, 10,"LOC"),]}),
("কালিহাতি", {"entities": [(0, 8,"LOC"),]}),
("কালীগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("কালুখালী", {"entities": [(0, 8,"LOC"),]}),
("কাশিয়ানী", {"entities": [(0, 9,"LOC"),]}),
("কাস্ট্রি", {"entities": [(0, 8,"LOC"),]}),
("কাহারোল", {"entities": [(0, 7,"LOC"),]}),
("কাহালু", {"entities": [(0, 6,"LOC"),]}),
("কায়রো", {"entities": [(0, 5,"LOC"),]}),
("কিংসটন", {"entities": [(0, 6,"LOC"),]}),
("কিংসটাউন", {"entities": [(0, 8,"LOC"),]}),
("কিউবা", {"entities": [(0, 5,"LOC"),]}),
("কিগালি", {"entities": [(0, 6,"LOC"),]}),
("কিনশাসা", {"entities": [(0, 7,"LOC"),]}),
("কিরগিজিস্তান", {"entities": [(0, 12,"LOC"),]}),
("কিরিবাতি", {"entities": [(0, 8,"LOC"),]}),
("কিশোরগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("কিয়েভ", {"entities": [(0, 5,"LOC"),]}),
("কুইটো", {"entities": [(0, 5,"LOC"),]}),
("কুড়িগ্রাম", {"entities": [(0, 10,"LOC"),]}),
("কুতুবদিয়া", {"entities": [(0, 10,"LOC"),]}),
("কুমারখালী", {"entities": [(0, 9,"LOC"),]}),
("কুমিল্লা", {"entities": [(0, 8,"LOC"),]}),
("কুলাউড়া", {"entities": [(0, 8,"LOC"),]}),
("কুলিয়ারচর", {"entities": [(0, 10,"LOC"),]}),
("কুষ্টিয়া", {"entities": [(0, 9,"LOC"),]}),
("কুষ্টিয়া", {"entities": [(0, 8,"LOC"),]}),
("কুড়িগ্রাম", {"entities": [(0, 9,"LOC"),]}),
("কুয়ালালামপুর", {"entities": [(0, 12,"LOC"),]}),
("কুয়েত", {"entities": [(0, 5,"LOC"),]}),
("কেউম্যান", {"entities": [(0, 8,"LOC"),]}),
("কেনিনং", {"entities": [(0, 6,"LOC"),]}),
("কেনিয়া", {"entities": [(0, 6,"LOC"),]}),
("কেন্দুয়া", {"entities": [(0, 9,"LOC"),]}),
("কেপটাউন", {"entities": [(0, 7,"LOC"),]}),
("কেপভার্দে", {"entities": [(0, 9,"LOC"),]}),
("কেরানীগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("কেশবপুর", {"entities": [(0, 7,"LOC"),]}),
("কোটচাঁদপুর", {"entities": [(0, 10,"LOC"),]}),
("কোটালীপাড়া", {"entities": [(0, 11,"LOC"),]}),
("কোনাক্রি", {"entities": [(0, 8,"LOC"),]}),
("কোপেন", {"entities": [(0, 5,"LOC"),]}),
("কোম্পানীগঞ্জ", {"entities": [(0, 12,"LOC"),]}),
("কোরিয়া", {"entities": [(0, 6,"LOC"),]}),
("কোস্টারিকা", {"entities": [(0, 10,"LOC"),]}),
("ক্যানবেরা", {"entities": [(0, 9,"LOC"),]}),
("ক্যামেরুন", {"entities": [(0, 9,"LOC"),]}),
("ক্রিস্টিনা", {"entities": [(0, 10,"LOC"),]}),
("ক্রোয়েশিয়া", {"entities": [(0, 10,"LOC"),]}),
("ক্ষেতলাল", {"entities": [(0, 8,"LOC"),]}),
("খাগড়াছড়ি", {"entities": [(0, 10,"LOC"),]}),
("খাগড়াছড়ি", {"entities": [(0, 8,"LOC"),]}),
("খানসামা", {"entities": [(0, 7,"LOC"),]}),
("খার্তুম", {"entities": [(0, 7,"LOC"),]}),
("খালিয়াজুড়ি", {"entities": [(0, 12,"LOC"),]}),
("খুলনা", {"entities": [(0, 5,"LOC"),]}),
("খোকসা", {"entities": [(0, 5,"LOC"),]}),
("গংগাচড়া", {"entities": [(0, 8,"LOC"),]}),
("গজারিয়া", {"entities": [(0, 8,"LOC"),]}),
("গফরগাঁও", {"entities": [(0, 7,"LOC"),]}),
("গলাচিপা", {"entities": [(0, 7,"LOC"),]}),
("গাংনী", {"entities": [(0, 5,"LOC"),]}),
("গাইবান্ধা", {"entities": [(0, 9,"LOC"),]}),
("গাজীপুর", {"entities": [(0, 7,"LOC"),]}),
("গাবতলী", {"entities": [(0, 6,"LOC"),]}),
("গাম্বিয়া", {"entities": [(0, 8,"LOC"),]}),
("গায়ানা", {"entities": [(0, 6,"LOC"),]}),
("গিনি", {"entities": [(0, 4,"LOC"),]}),
("গুইমারা", {"entities": [(0, 7,"LOC"),]}),
("গুরুদাসপুর", {"entities": [(0, 10,"LOC"),]}),
("গুর্দে", {"entities": [(0, 6,"LOC"),]}),
("গুয়েতেমালা", {"entities": [(0, 10,"LOC"),]}),
("গোদাগারী", {"entities": [(0, 8,"LOC"),]}),
("গোপালগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("গোপালপুর", {"entities": [(0, 8,"LOC"),]}),
("গোবিন্দগঞ্জ", {"entities": [(0, 11,"LOC"),]}),
("গোমস্তাপুর", {"entities": [(0, 10,"LOC"),]}),
("গোয়াইনঘাট", {"entities": [(0, 10,"LOC"),]}),
("গোয়ালন্দ", {"entities": [(0, 9,"LOC"),]}),
("গোলাপগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("গোসাইরহাট", {"entities": [(0, 9,"LOC"),]}),
("গৌরনদী", {"entities": [(0, 6,"LOC"),]}),
("গৌরীপুর", {"entities": [(0, 7,"LOC"),]}),
("গ্যাবন", {"entities": [(0, 6,"LOC"),]}),
("গ্যাবরন", {"entities": [(0, 7,"LOC"),]}),
("গ্রানাডা", {"entities": [(0, 8,"LOC"),]}),
("গ্রিস", {"entities": [(0, 5,"LOC"),]}),
("ঘাটাইল", {"entities": [(0, 6,"LOC"),]}),
("ঘানা", {"entities": [(0, 4,"LOC"),]}),
("ঘিওর", {"entities": [(0, 4,"LOC"),]}),
("ঘোড়াঘাট", {"entities": [(0, 8,"LOC"),]}),
("চকরিয়া", {"entities": [(0, 7,"LOC"),]}),
("চট্টগ্রাম", {"entities": [(0, 9,"LOC"),]}),
("চট্রগ্রাম", {"entities": [(0, 9,"LOC"),]}),
("চন্দনাইশ", {"entities": [(0, 8,"LOC"),]}),
("চর", {"entities": [(0, 2,"LOC"),]}),
("চরফ্যাশন", {"entities": [(0, 8,"LOC"),]}),
("চাঁদপুর", {"entities": [(0, 7,"LOC"),]}),
("চাঁপাইনবাবগঞ্জ", {"entities": [(0, 14,"LOC"),]}),
("চাটখিল", {"entities": [(0, 6,"LOC"),]}),
("চাটমোহর", {"entities": [(0, 7,"LOC"),]}),
("চাদ", {"entities": [(0, 3,"LOC"),]}),
("চান্দিনা", {"entities": [(0, 8,"LOC"),]}),
("চারঘাট", {"entities": [(0, 6,"LOC"),]}),
("চিতলমারী", {"entities": [(0, 8,"LOC"),]}),
("চিরিরবন্দর", {"entities": [(0, 10,"LOC"),]}),
("চিলমারী", {"entities": [(0, 7,"LOC"),]}),
("চিলি", {"entities": [(0, 4,"LOC"),]}),
("চিসিনিউ", {"entities": [(0, 7,"LOC"),]}),
("চীন", {"entities": [(0, 3,"LOC"),]}),
("চুনারুঘাট", {"entities": [(0, 9,"LOC"),]}),
("চুয়াডাঙ্গা", {"entities": [(0, 11,"LOC"),]}),
("চুয়াডাঙ্গা", {"entities": [(0, 10,"LOC"),]}),
("চেক", {"entities": [(0, 3,"LOC"),]}),
("চৌগাছা", {"entities": [(0, 6,"LOC"),]}),
("চৌদ্দগ্রাম", {"entities": [(0, 10,"LOC"),]}),
("চৌহালি", {"entities": [(0, 6,"LOC"),]}),
("ছাগলনাইয়া", {"entities": [(0, 10,"LOC"),]}),
("ছাতক", {"entities": [(0, 4,"LOC"),]}),
("জকিগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("জগন্নাথপুর", {"entities": [(0, 10,"LOC"),]}),
("জয়পুরহাট", {"entities": [(0, 9,"LOC"),]}),
("জর্জটাউন", {"entities": [(0, 8,"LOC"),]}),
("জর্জিয়া", {"entities": [(0, 7,"LOC"),]}),
("জর্জেস", {"entities": [(0, 6,"LOC"),]}),
("জর্ডান", {"entities": [(0, 6,"LOC"),]}),
("জলঢাকা", {"entities": [(0, 6,"LOC"),]}),
("জাকার্তা", {"entities": [(0, 8,"LOC"),]}),
("জাগোরেব", {"entities": [(0, 7,"LOC"),]}),
("জাজিরা", {"entities": [(0, 6,"LOC"),]}),
("জামালগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("জামালপুর", {"entities": [(0, 8,"LOC"),]}),
("জাম্বিয়া", {"entities": [(0, 8,"LOC"),]}),
("জার্মানি", {"entities": [(0, 8,"LOC"),]}),
("জায়ারে", {"entities": [(0, 6,"LOC"),]}),
("জিবুতি", {"entities": [(0, 6,"LOC"),]}),
("জিম্বাবুয়ে", {"entities": [(0, 10,"LOC"),]}),
("জিয়ানগর", {"entities": [(0, 8,"LOC"),]}),
("জীবননগর", {"entities": [(0, 7,"LOC"),]}),
("জুড়ী", {"entities": [(0, 5,"LOC"),]}),
("জুরা", {"entities": [(0, 4,"LOC"),]}),
("জুরাছড়ি", {"entities": [(0, 8,"LOC"),]}),
("জেরুজালেম", {"entities": [(0, 9,"LOC"),]}),
("জৈন্তাপুর", {"entities": [(0, 9,"LOC"),]}),
("জোনস", {"entities": [(0, 4,"LOC"),]}),
("জ্যামাইকা", {"entities": [(0, 9,"LOC"),]}),
("জয়পুরহাট", {"entities": [(0, 8,"LOC"),]}),
("ঝালকাঠি", {"entities": [(0, 7,"LOC"),]}),
("ঝালকাঠী", {"entities": [(0, 7,"LOC"),]}),
("ঝিকরগাছা", {"entities": [(0, 8,"LOC"),]}),
("ঝিনাইগাতী", {"entities": [(0, 9,"LOC"),]}),
("ঝিনাইদহ", {"entities": [(0, 7,"LOC"),]}),
("টঙ্গীবাড়ী", {"entities": [(0, 10,"LOC"),]}),
("টাঙ্গাইল", {"entities": [(0, 8,"LOC"),]}),
("টুঙ্গিপাড়া", {"entities": [(0, 11,"LOC"),]}),
("টেকনাফ", {"entities": [(0, 6,"LOC"),]}),
("টোকিও", {"entities": [(0, 5,"LOC"),]}),
("টোগো", {"entities": [(0, 4,"LOC"),]}),
("টোঙ্গো", {"entities": [(0, 6,"LOC"),]}),
("টোবাগো", {"entities": [(0, 6,"LOC"),]}),
("ট্রুভ্যালু", {"entities": [(0, 10,"LOC"),]}),
("ঠাকুরগাঁও", {"entities": [(0, 9,"LOC"),]}),
("ডাকার", {"entities": [(0, 5,"LOC"),]}),
("ডাবলিন", {"entities": [(0, 6,"LOC"),]}),
("ডামুড্যা", {"entities": [(0, 8,"LOC"),]}),
("ডিমলা", {"entities": [(0, 5,"LOC"),]}),
("ডিসি", {"entities": [(0, 4,"LOC"),]}),
("ডুমুরিয়া", {"entities": [(0, 9,"LOC"),]}),
("ডেনমার্ক", {"entities": [(0, 8,"LOC"),]}),
("ডোমার", {"entities": [(0, 5,"LOC"),]}),
("ডোমিনিকা", {"entities": [(0, 8,"LOC"),]}),
("ডোমিনিকান", {"entities": [(0, 9,"LOC"),]}),
("ডোমিনিগো", {"entities": [(0, 8,"LOC"),]}),
("ঢাকা", {"entities": [(0, 4,"LOC"),]}),
("তজমুদ্দিন", {"entities": [(0, 9,"LOC"),]}),
("তাইওয়ান", {"entities": [(0, 7,"LOC"),]}),
("তাইপে", {"entities": [(0, 5,"LOC"),]}),
("তাজিকিস্তান", {"entities": [(0, 11,"LOC"),]}),
("তাড়াইল", {"entities": [(0, 7,"LOC"),]}),
("তাড়াশ", {"entities": [(0, 6,"LOC"),]}),
("তানজানিয়া", {"entities": [(0, 9,"LOC"),]}),
("তানোর", {"entities": [(0, 5,"LOC"),]}),
("তারাওয়া", {"entities": [(0, 7,"LOC"),]}),
("তারাকান্দা", {"entities": [(0, 10,"LOC"),]}),
("তারাগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("তালতলী", {"entities": [(0, 6,"LOC"),]}),
("তালা", {"entities": [(0, 4,"LOC"),]}),
("তাল্লিন", {"entities": [(0, 7,"LOC"),]}),
("তাশখন্দ", {"entities": [(0, 7,"LOC"),]}),
("তাহিরপুর", {"entities": [(0, 8,"LOC"),]}),
("তিউনিশ", {"entities": [(0, 6,"LOC"),]}),
("তিউনিশিয়া", {"entities": [(0, 9,"LOC"),]}),
("তিতাস", {"entities": [(0, 5,"LOC"),]}),
("তিবলিস", {"entities": [(0, 6,"LOC"),]}),
("তিরানা", {"entities": [(0, 6,"LOC"),]}),
("তুরস্ক", {"entities": [(0, 6,"LOC"),]}),
("তুর্কমেনিস্তান", {"entities": [(0, 14,"LOC"),]}),
("তেগুচিগালপা", {"entities": [(0, 11,"LOC"),]}),
("তেতুলিয়া", {"entities": [(0, 9,"LOC"),]}),
("তেরখাদা", {"entities": [(0, 7,"LOC"),]}),
("তেহরান", {"entities": [(0, 6,"LOC"),]}),
("ত্রিনিদাদ", {"entities": [(0, 9,"LOC"),]}),
("ত্রিপলি", {"entities": [(0, 7,"LOC"),]}),
("ত্রিশাল", {"entities": [(0, 7,"LOC"),]}),
("থাইল্যান্ড", {"entities": [(0, 10,"LOC"),]}),
("থানচি", {"entities": [(0, 5,"LOC"),]}),
("থিম্পু", {"entities": [(0, 6,"LOC"),]}),
("দক্ষিণ", {"entities": [(0, 6,"LOC"),]}),
("দশমিনা", {"entities": [(0, 6,"LOC"),]}),
("দাউদকান্দি", {"entities": [(0, 10,"LOC"),]}),
("দাকোপ", {"entities": [(0, 5,"LOC"),]}),
("দাগনভূঁইয়া", {"entities": [(0, 11,"LOC"),]}),
("দামুড়হুদা", {"entities": [(0, 10,"LOC"),]}),
("দামেস্ক", {"entities": [(0, 7,"LOC"),]}),
("দারুস", {"entities": [(0, 5,"LOC"),]}),
("দিঘলিয়া", {"entities": [(0, 8,"LOC"),]}),
("দিনাজপুর", {"entities": [(0, 8,"LOC"),]}),
("দিরাই", {"entities": [(0, 5,"LOC"),]}),
("দিলি", {"entities": [(0, 4,"LOC"),]}),
("দীঘিনালা", {"entities": [(0, 8,"LOC"),]}),
("দুমকি", {"entities": [(0, 5,"LOC"),]}),
("দুর্গাপুর", {"entities": [(0, 9,"LOC"),]}),
("দুশানবে", {"entities": [(0, 7,"LOC"),]}),
("দূর্গাপুর", {"entities": [(0, 9,"LOC"),]}),
("দেওয়ানগঞ্জ", {"entities": [(0, 11,"LOC"),]}),
("দেবহাটা", {"entities": [(0, 7,"LOC"),]}),
("দেবীগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("দেবীদ্বার", {"entities": [(0, 9,"LOC"),]}),
("দেলদুয়ার", {"entities": [(0, 9,"LOC"),]}),
("দেশের", {"entities": [(0, 5,"LOC"),]}),
("দোয়ারাবাজার", {"entities": [(0, 12,"LOC"),]}),
("দোহা", {"entities": [(0, 4,"LOC"),]}),
("দোহার", {"entities": [(0, 5,"LOC"),]}),
("দৌলতখান", {"entities": [(0, 7,"LOC"),]}),
("দৌলতপুর", {"entities": [(0, 7,"LOC"),]}),
("দ্বীপপুঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("দ্যা", {"entities": [(0, 4,"LOC"),]}),
("ধনবাড়ী", {"entities": [(0, 7,"LOC"),]}),
("ধর্মপাশা", {"entities": [(0, 8,"LOC"),]}),
("ধামরাই", {"entities": [(0, 6,"LOC"),]}),
("ধামুরহাট", {"entities": [(0, 8,"LOC"),]}),
("ধুনট", {"entities": [(0, 4,"LOC"),]}),
("ধুপচাঁচিয়া", {"entities": [(0, 11,"LOC"),]}),
("ধোবাউড়া", {"entities": [(0, 8,"LOC"),]}),
("নওগাঁ", {"entities": [(0, 5,"LOC"),]}),
("নকলা", {"entities": [(0, 4,"LOC"),]}),
("নগরকান্দা", {"entities": [(0, 9,"LOC"),]}),
("নড়াইল", {"entities": [(0, 6,"LOC"),]}),
("নড়িয়া", {"entities": [(0, 7,"LOC"),]}),
("নন্দীগ্রাম", {"entities": [(0, 10,"LOC"),]}),
("নবাবগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("নবীগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("নবীনগর", {"entities": [(0, 6,"LOC"),]}),
("নমপেন", {"entities": [(0, 5,"LOC"),]}),
("নরওয়ে", {"entities": [(0, 5,"LOC"),]}),
("নরসিংদী", {"entities": [(0, 7,"LOC"),]}),
("নলছিটি", {"entities": [(0, 6,"LOC"),]}),
("নলডাঙ্গা", {"entities": [(0, 8,"LOC"),]}),
("নাইক্ষ্যংছড়ি", {"entities": [(0, 13,"LOC"),]}),
("নাইজার", {"entities": [(0, 6,"LOC"),]}),
("নাইজেরিয়া", {"entities": [(0, 9,"LOC"),]}),
("নাইপিদো", {"entities": [(0, 7,"LOC"),]}),
("নাইরোবি", {"entities": [(0, 7,"LOC"),]}),
("নাউরু", {"entities": [(0, 5,"LOC"),]}),
("নাগরপুর", {"entities": [(0, 7,"LOC"),]}),
("নাগেশ্বরী", {"entities": [(0, 9,"LOC"),]}),
("নাচোল", {"entities": [(0, 5,"LOC"),]}),
("নাজিরপুর", {"entities": [(0, 8,"LOC"),]}),
("নাটোর", {"entities": [(0, 5,"LOC"),]}),
("নানারিভো", {"entities": [(0, 8,"LOC"),]}),
("নানিয়াচর", {"entities": [(0, 9,"LOC"),]}),
("নান্দাইল", {"entities": [(0, 8,"LOC"),]}),
("নাম", {"entities": [(0, 3,"LOC"),]}),
("নামটি", {"entities": [(0, 5,"LOC"),]}),
("নামিবিয়া", {"entities": [(0, 8,"LOC"),]}),
("নামে", {"entities": [(0, 4,"LOC"),]}),
("নামের", {"entities": [(0, 5,"LOC"),]}),
("নারায়ণগঞ্জ", {"entities": [(0, 11,"LOC"),]}),
("নারায়নগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("নালিতাবাড়ী", {"entities": [(0, 11,"LOC"),]}),
("নাসাউ", {"entities": [(0, 5,"LOC"),]}),
("নাসিরনগর", {"entities": [(0, 8,"LOC"),]}),
("নিউগিনি", {"entities": [(0, 7,"LOC"),]}),
("নিউজিল্যান্ড", {"entities": [(0, 12,"LOC"),]}),
("নিকলী", {"entities": [(0, 5,"LOC"),]}),
("নিকারাগুয়া", {"entities": [(0, 10,"LOC"),]}),
("নিকোশিয়া", {"entities": [(0, 8,"LOC"),]}),
("নিয়ামতপুর", {"entities": [(0, 10,"LOC"),]}),
("নিয়ামি", {"entities": [(0, 6,"LOC"),]}),
("নীলফামারী", {"entities": [(0, 9,"LOC"),]}),
("নুকুয়ালোফা", {"entities": [(0, 10,"LOC"),]}),
("নেগারুলমার্ড", {"entities": [(0, 12,"LOC"),]}),
("নেছারাবাদ", {"entities": [(0, 9,"LOC"),]}),
("নেত্রকোণা", {"entities": [(0, 9,"LOC"),]}),
("নেত্রকোনা", {"entities": [(0, 9,"LOC"),]}),
("নেদারল্যান্ড", {"entities": [(0, 12,"LOC"),]}),
("নেপাল", {"entities": [(0, 5,"LOC"),]}),
("নোভা", {"entities": [(0, 4,"LOC"),]}),
("নোয়াখালী", {"entities": [(0, 9,"LOC"),]}),
("নোয়াখালী", {"entities": [(0, 8,"LOC"),]}),
("নৌয়াকচট", {"entities": [(0, 7,"LOC"),]}),
("নড়াইল", {"entities": [(0, 5,"LOC"),]}),
("নয়াদিল্লী", {"entities": [(0, 9,"LOC"),]}),
("পঞ্চগড়", {"entities": [(0, 7,"LOC"),]}),
("পঞ্চগড়", {"entities": [(0, 6,"LOC"),]}),
("পটিয়া", {"entities": [(0, 6,"LOC"),]}),
("পটুয়াখালী", {"entities": [(0, 10,"LOC"),]}),
("পটুয়াখালী", {"entities": [(0, 9,"LOC"),]}),
("পত্নীতলা", {"entities": [(0, 8,"LOC"),]}),
("পবা", {"entities": [(0, 3,"LOC"),]}),
("পরশা", {"entities": [(0, 4,"LOC"),]}),
("পরশুরাম", {"entities": [(0, 7,"LOC"),]}),
("পর্তুগাল", {"entities": [(0, 8,"LOC"),]}),
("পলাশ", {"entities": [(0, 4,"LOC"),]}),
("পলাশবাড়ী", {"entities": [(0, 9,"LOC"),]}),
("পলিনেশিয়া", {"entities": [(0, 9,"LOC"),]}),
("পশ্চিম", {"entities": [(0, 6,"LOC"),]}),
("পশ্চিমবঙ্গ", {"entities": [(0, 10,"LOC"),]}),
("পাঁচবিবি", {"entities": [(0, 8,"LOC"),]}),
("পাংশা", {"entities": [(0, 5,"LOC"),]}),
("পাইকগাছা", {"entities": [(0, 8,"LOC"),]}),
("পাকিস্তান", {"entities": [(0, 9,"LOC"),]}),
("পাকিস্তানের", {"entities": [(0, 11,"LOC"),]}),
("পাকুন্দিয়া", {"entities": [(0, 11,"LOC"),]}),
("পাটগ্রাম", {"entities": [(0, 8,"LOC"),]}),
("পাথরঘাটা", {"entities": [(0, 8,"LOC"),]}),
("পানছড়ি", {"entities": [(0, 7,"LOC"),]}),
("পানামা", {"entities": [(0, 6,"LOC"),]}),
("পাপুয়া", {"entities": [(0, 6,"LOC"),]}),
("পাপেট্রি", {"entities": [(0, 8,"LOC"),]}),
("পাবনা", {"entities": [(0, 5,"LOC"),]}),
("পারামারিবো", {"entities": [(0, 10,"LOC"),]}),
("পার্বতীপুর", {"entities": [(0, 10,"LOC"),]}),
("পালাউ", {"entities": [(0, 5,"LOC"),]}),
("পালিকির", {"entities": [(0, 7,"LOC"),]}),
("পিরোজপুর", {"entities": [(0, 8,"LOC"),]}),
("পিয়ংইয়ং", {"entities": [(0, 7,"LOC"),]}),
("পীরগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("পীরগাছা", {"entities": [(0, 7,"LOC"),]}),
("পুঠিয়া", {"entities": [(0, 7,"LOC"),]}),
("পুর্টলুইস", {"entities": [(0, 9,"LOC"),]}),
("পূর্বধলা", {"entities": [(0, 8,"LOC"),]}),
("পেকুয়া", {"entities": [(0, 7,"LOC"),]}),
("পেরু", {"entities": [(0, 4,"LOC"),]}),
("পোডগোরিকো", {"entities": [(0, 9,"LOC"),]}),
("পোর্ট", {"entities": [(0, 5,"LOC"),]}),
("পোর্ট্রো", {"entities": [(0, 8,"LOC"),]}),
("পোয়েটরিকো", {"entities": [(0, 9,"LOC"),]}),
("প্যারাগুয়ে", {"entities": [(0, 10,"LOC"),]}),
("প্যারিস", {"entities": [(0, 7,"LOC"),]}),
("প্রজাতন্ত্র", {"entities": [(0, 11,"LOC"),]}),
("প্রাগ", {"entities": [(0, 5,"LOC"),]}),
("প্রিন্স", {"entities": [(0, 7,"LOC"),]}),
("প্রিন্সিপি", {"entities": [(0, 10,"LOC"),]}),
("প্রেইরা", {"entities": [(0, 7,"LOC"),]}),
("ফকিরহাট", {"entities": [(0, 7,"LOC"),]}),
("ফটিকছড়ি", {"entities": [(0, 8,"LOC"),]}),
("ফরিদগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("ফরিদপুর", {"entities": [(0, 7,"LOC"),]}),
("ফাসো", {"entities": [(0, 4,"LOC"),]}),
("ফিজি", {"entities": [(0, 4,"LOC"),]}),
("ফিনল্যান্ড", {"entities": [(0, 10,"LOC"),]}),
("ফিলিপাইন", {"entities": [(0, 8,"LOC"),]}),
("ফিলিস্তিন", {"entities": [(0, 9,"LOC"),]}),
("ফুনাফুটি", {"entities": [(0, 8,"LOC"),]}),
("ফুলগাজী", {"entities": [(0, 7,"LOC"),]}),
("ফুলছড়ি", {"entities": [(0, 7,"LOC"),]}),
("ফুলতলা", {"entities": [(0, 6,"LOC"),]}),
("ফুলপুর", {"entities": [(0, 6,"LOC"),]}),
("ফুলবাড়িয়া", {"entities": [(0, 11,"LOC"),]}),
("ফুলবাড়ী", {"entities": [(0, 8,"LOC"),]}),
("ফেঞ্চুগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("ফেনী", {"entities": [(0, 4,"LOC"),]}),
("ফ্রান্স", {"entities": [(0, 7,"LOC"),]}),
("ফ্রিটাউন", {"entities": [(0, 8,"LOC"),]}),
("ফ্রেঞ্চ", {"entities": [(0, 7,"LOC"),]}),
("ফ্রেঞ্চগায়ানা", {"entities": [(0, 13,"LOC"),]}),
("বকশীগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("বগুড়া", {"entities": [(0, 6,"LOC"),]}),
("বগুড়া", {"entities": [(0, 5,"LOC"),]}),
("বগোটা", {"entities": [(0, 5,"LOC"),]}),
("বটিয়াঘাটা", {"entities": [(0, 10,"LOC"),]}),
("বড়লেখা", {"entities": [(0, 7,"LOC"),]}),
("বদরগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("বদলগাছী", {"entities": [(0, 7,"LOC"),]}),
("বন্দর", {"entities": [(0, 5,"LOC"),]}),
("বরকল", {"entities": [(0, 4,"LOC"),]}),
("বরগুনা", {"entities": [(0, 6,"LOC"),]}),
("বরাইগ্রাম", {"entities": [(0, 9,"LOC"),]}),
("বরিশাল", {"entities": [(0, 6,"LOC"),]}),
("বরুরা", {"entities": [(0, 5,"LOC"),]}),
("বলিভিয়া", {"entities": [(0, 7,"LOC"),]}),
("বসনিয়া", {"entities": [(0, 6,"LOC"),]}),
("বাঁশখালী", {"entities": [(0, 8,"LOC"),]}),
("বাংলাদেশ", {"entities": [(0, 8,"LOC"),]}),
("বাংলাদেশে", {"entities": [(0, 9,"LOC"),]}),
("বাংলাদেশের", {"entities": [(0, 10,"LOC"),]}),
("বাউফল", {"entities": [(0, 5,"LOC"),]}),
("বাকেরগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("বাগদাদ", {"entities": [(0, 6,"LOC"),]}),
("বাগমারা", {"entities": [(0, 7,"LOC"),]}),
("বাগাতিপাড়া", {"entities": [(0, 11,"LOC"),]}),
("বাগেরহাট", {"entities": [(0, 8,"LOC"),]}),
("বাগেরহাটের", {"entities": [(0, 10,"LOC"),]}),
("বাঘা", {"entities": [(0, 4,"LOC"),]}),
("বাঘাইছড়ি", {"entities": [(0, 9,"LOC"),]}),
("বাঘারপাড়া", {"entities": [(0, 10,"LOC"),]}),
("বাঙ্গুই", {"entities": [(0, 7,"LOC"),]}),
("বাজিতপুর", {"entities": [(0, 8,"LOC"),]}),
("বাঞ্ছারামপুর", {"entities": [(0, 12,"LOC"),]}),
("বানজুল", {"entities": [(0, 6,"LOC"),]}),
("বানারীপাড়া", {"entities": [(0, 11,"LOC"),]}),
("বানিয়াচং", {"entities": [(0, 9,"LOC"),]}),
("বান্দরবান", {"entities": [(0, 9,"LOC"),]}),
("বাবুগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("বাবেন", {"entities": [(0, 5,"LOC"),]}),
("বামনা", {"entities": [(0, 5,"LOC"),]}),
("বামাকো", {"entities": [(0, 6,"LOC"),]}),
("বারবাডোজ", {"entities": [(0, 8,"LOC"),]}),
("বারমুডা", {"entities": [(0, 7,"LOC"),]}),
("বারহাট্টা", {"entities": [(0, 9,"LOC"),]}),
("বার্ন", {"entities": [(0, 5,"LOC"),]}),
("বার্লিন", {"entities": [(0, 7,"LOC"),]}),
("বালাগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("বালিয়াকান্দি", {"entities": [(0, 13,"LOC"),]}),
("বালিয়াডাঙ্গী", {"entities": [(0, 13,"LOC"),]}),
("বাসটেরে", {"entities": [(0, 7,"LOC"),]}),
("বাসাইল", {"entities": [(0, 6,"LOC"),]}),
("বাহরাইন", {"entities": [(0, 7,"LOC"),]}),
("বাহামা", {"entities": [(0, 6,"LOC"),]}),
("বাহুবল", {"entities": [(0, 6,"LOC"),]}),
("বিজয়নগর", {"entities": [(0, 8,"LOC"),]}),
("বিভাগের", {"entities": [(0, 7,"LOC"),]}),
("বিয়ানীবাজার", {"entities": [(0, 12,"LOC"),]}),
("বির", {"entities": [(0, 3,"LOC"),]}),
("বিরল", {"entities": [(0, 4,"LOC"),]}),
("বিরামপুর", {"entities": [(0, 8,"LOC"),]}),
("বিরুদ্ধে", {"entities": [(0, 8,"LOC"),]}),
("বিলাইছড়ি", {"entities": [(0, 9,"LOC"),]}),
("বিশবেক", {"entities": [(0, 6,"LOC"),]}),
("বিশ্বনাথ", {"entities": [(0, 8,"LOC"),]}),
("বিশ্বম্ভরপুর", {"entities": [(0, 12,"LOC"),]}),
("বিসাউ", {"entities": [(0, 5,"LOC"),]}),
("বিসাও", {"entities": [(0, 5,"LOC"),]}),
("বীরগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("বুখারেস্ট", {"entities": [(0, 9,"LOC"),]}),
("বুজুমবুরা", {"entities": [(0, 9,"LOC"),]}),
("বুড়িচং", {"entities": [(0, 7,"LOC"),]}),
("বুদাপেস্ট", {"entities": [(0, 9,"LOC"),]}),
("বুরকিনা", {"entities": [(0, 7,"LOC"),]}),
("বুরুন্ডি", {"entities": [(0, 8,"LOC"),]}),
("বুলগেরিয়া", {"entities": [(0, 9,"LOC"),]}),
("বুয়েন্স", {"entities": [(0, 7,"LOC"),]}),
("বেইজিংজাপান", {"entities": [(0, 11,"LOC"),]}),
("বেগমগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("বেড়া", {"entities": [(0, 5,"LOC"),]}),
("বেতাগি", {"entities": [(0, 6,"LOC"),]}),
("বেনিন", {"entities": [(0, 5,"LOC"),]}),
("বেলকুচি", {"entities": [(0, 7,"LOC"),]}),
("বেলগ্রেড", {"entities": [(0, 8,"LOC"),]}),
("বেলজিয়াম", {"entities": [(0, 8,"LOC"),]}),
("বেলমোপান", {"entities": [(0, 8,"LOC"),]}),
("বেলাবো", {"entities": [(0, 6,"LOC"),]}),
("বেলারুশ", {"entities": [(0, 7,"LOC"),]}),
("বেলিজ", {"entities": [(0, 5,"LOC"),]}),
("বৈরুত", {"entities": [(0, 5,"LOC"),]}),
("বোচাগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("বোতসোয়ানা", {"entities": [(0, 9,"LOC"),]}),
("বোদা", {"entities": [(0, 4,"LOC"),]}),
("বোয়ালখালী", {"entities": [(0, 10,"LOC"),]}),
("বোয়ালমারী", {"entities": [(0, 10,"LOC"),]}),
("বোরহানউদ্দিন", {"entities": [(0, 12,"LOC"),]}),
("ব্যাংকক", {"entities": [(0, 7,"LOC"),]}),
("ব্রজাভিল", {"entities": [(0, 8,"LOC"),]}),
("ব্রাক্ষ্মণবাড়িয়া", {"entities": [(0, 16,"LOC"),]}),
("ব্রাজিল", {"entities": [(0, 7,"LOC"),]}),
("ব্রাসিলিয়া", {"entities": [(0, 10,"LOC"),]}),
("ব্রাসেলস", {"entities": [(0, 8,"LOC"),]}),
("ব্রাহ্মণপাড়া", {"entities": [(0, 13,"LOC"),]}),
("ব্রাহ্মণবাড়িয়া", {"entities": [(0, 16,"LOC"),]}),
("ব্রিজটাউন", {"entities": [(0, 9,"LOC"),]}),
("ব্রুনাই", {"entities": [(0, 7,"LOC"),]}),
("ব্লাটিস্লাভা", {"entities": [(0, 12,"LOC"),]}),
("ভদ্রাসন", {"entities": [(0, 7,"LOC"),]}),
("ভাঙ্গা", {"entities": [(0, 6,"LOC"),]}),
("ভাঙ্গুরা", {"entities": [(0, 8,"LOC"),]}),
("ভাণ্ডারিয়া", {"entities": [(0, 11,"LOC"),]}),
("ভাদুজ", {"entities": [(0, 5,"LOC"),]}),
("ভানুয়াতু", {"entities": [(0, 8,"LOC"),]}),
("ভারত", {"entities": [(0, 4,"LOC"),]}),
("ভারতের", {"entities": [(0, 6,"LOC"),]}),
("ভালুকা", {"entities": [(0, 6,"LOC"),]}),
("ভালেটা", {"entities": [(0, 6,"LOC"),]}),
("ভিক্টোরিয়া", {"entities": [(0, 10,"LOC"),]}),
("ভিনসেন্ট", {"entities": [(0, 8,"LOC"),]}),
("ভিনিয়াস", {"entities": [(0, 7,"LOC"),]}),
("ভিলা", {"entities": [(0, 4,"LOC"),]}),
("ভিয়েতনাম", {"entities": [(0, 8,"LOC"),]}),
("ভিয়েনা", {"entities": [(0, 6,"LOC"),]}),
("ভুটান", {"entities": [(0, 5,"LOC"),]}),
("ভুরুঙ্গামারী", {"entities": [(0, 12,"LOC"),]}),
("ভূঞাপুর", {"entities": [(0, 7,"LOC"),]}),
("ভেড়ামারা", {"entities": [(0, 9,"LOC"),]}),
("ভেদরগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("ভেনিজুয়েলা", {"entities": [(0, 10,"LOC"),]}),
("ভৈরব", {"entities": [(0, 4,"LOC"),]}),
("ভোলা", {"entities": [(0, 4,"LOC"),]}),
("ভোলাহাট", {"entities": [(0, 7,"LOC"),]}),
("ভ্যাটিকাস", {"entities": [(0, 9,"LOC"),]}),
("ভ্যালি", {"entities": [(0, 6,"LOC"),]}),
("মঙ্গোলিয়া", {"entities": [(0, 9,"LOC"),]}),
("মঠবাড়িয়া", {"entities": [(0, 10,"LOC"),]}),
("মতলব", {"entities": [(0, 4,"LOC"),]}),
("মদন", {"entities": [(0, 3,"LOC"),]}),
("মধুখালী", {"entities": [(0, 7,"LOC"),]}),
("মধুপুর", {"entities": [(0, 6,"LOC"),]}),
("মধ্য", {"entities": [(0, 4,"LOC"),]}),
("মধ্যবিত্ত", {"entities": [(0, 9,"LOC"),]}),
("মধ্যে", {"entities": [(0, 5,"LOC"),]}),
("মনপুরা", {"entities": [(0, 6,"LOC"),]}),
("মনরোভিয়া", {"entities": [(0, 8,"LOC"),]}),
("মনিরামপুর", {"entities": [(0, 9,"LOC"),]}),
("মনোহরগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("মনোহরদী", {"entities": [(0, 7,"LOC"),]}),
("মন্টিনিগ্রো", {"entities": [(0, 11,"LOC"),]}),
("মন্টিভিডিও", {"entities": [(0, 10,"LOC"),]}),
("ময়মনসিংহ", {"entities": [(0, 9,"LOC"),]}),
("মরক্কো", {"entities": [(0, 6,"LOC"),]}),
("মলদোভা", {"entities": [(0, 6,"LOC"),]}),
("মস্কো", {"entities": [(0, 5,"LOC"),]}),
("মহাদেবপুর", {"entities": [(0, 9,"LOC"),]}),
("মহালছড়ি", {"entities": [(0, 8,"LOC"),]}),
("মহেশখালী", {"entities": [(0, 8,"LOC"),]}),
("মহেশপুর", {"entities": [(0, 7,"LOC"),]}),
("মাইক্রোনেশিয়া", {"entities": [(0, 13,"LOC"),]}),
("মাগুরা", {"entities": [(0, 6,"LOC"),]}),
("মাজুরো", {"entities": [(0, 6,"LOC"),]}),
("মাটিরাঙ্গা", {"entities": [(0, 10,"LOC"),]}),
("মাদারগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("মাদারিপুর", {"entities": [(0, 9,"LOC"),]}),
("মাদারীপুর", {"entities": [(0, 9,"LOC"),]}),
("মাদ্রিদনং", {"entities": [(0, 9,"LOC"),]}),
("মাধবপুর", {"entities": [(0, 7,"LOC"),]}),
("মানাগুয়া", {"entities": [(0, 8,"LOC"),]}),
("মানামা", {"entities": [(0, 6,"LOC"),]}),
("মানিকগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("মানিকছড়ি", {"entities": [(0, 9,"LOC"),]}),
("মান্দা", {"entities": [(0, 6,"LOC"),]}),
("মাপুতো", {"entities": [(0, 6,"LOC"),]}),
("মার্শাল", {"entities": [(0, 7,"LOC"),]}),
("মালটা", {"entities": [(0, 5,"LOC"),]}),
("মালদ্বীপ", {"entities": [(0, 8,"LOC"),]}),
("মালাগাছি", {"entities": [(0, 8,"LOC"),]}),
("মালাবি", {"entities": [(0, 6,"LOC"),]}),
("মালাবো", {"entities": [(0, 6,"LOC"),]}),
("মালি", {"entities": [(0, 4,"LOC"),]}),
("মালে", {"entities": [(0, 4,"LOC"),]}),
("মালেশিয়া", {"entities": [(0, 8,"LOC"),]}),
("মালয়েশিয়া", {"entities": [(0, 9,"LOC"),]}),
("মাসকট", {"entities": [(0, 5,"LOC"),]}),
("মাসেরো", {"entities": [(0, 6,"LOC"),]}),
("মায়ানমার", {"entities": [(0, 8,"LOC"),]}),
("মিটামইন", {"entities": [(0, 7,"LOC"),]}),
("মিঠাপুকুর", {"entities": [(0, 9,"LOC"),]}),
("মিনস্ক", {"entities": [(0, 6,"LOC"),]}),
("মিরপুর", {"entities": [(0, 6,"LOC"),]}),
("মির্জাগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("মির্জাপুর", {"entities": [(0, 9,"LOC"),]}),
("মিশর", {"entities": [(0, 4,"LOC"),]}),
("মীরসরাই", {"entities": [(0, 7,"LOC"),]}),
("মুকসুদপুর", {"entities": [(0, 9,"LOC"),]}),
("মুক্তাগাছা", {"entities": [(0, 10,"LOC"),]}),
("মুজিবনগর", {"entities": [(0, 8,"LOC"),]}),
("মুন্সিগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("মুন্সীগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("মুরাদনগর", {"entities": [(0, 8,"LOC"),]}),
("মুলাদী", {"entities": [(0, 6,"LOC"),]}),
("মেক্সিকো", {"entities": [(0, 8,"LOC"),]}),
("মেঘনা", {"entities": [(0, 5,"LOC"),]}),
("মেলান্দহ", {"entities": [(0, 8,"LOC"),]}),
("মেসিডোনিয়া", {"entities": [(0, 10,"LOC"),]}),
("মেহেন্দিগঞ্জ", {"entities": [(0, 12,"LOC"),]}),
("মেহেরপুর", {"entities": [(0, 8,"LOC"),]}),
("মোংলা", {"entities": [(0, 5,"LOC"),]}),
("মোগাদিসু", {"entities": [(0, 8,"LOC"),]}),
("মোজাম্বিক", {"entities": [(0, 9,"LOC"),]}),
("মোড়েলগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("মোনাকো", {"entities": [(0, 6,"LOC"),]}),
("মোরোনি", {"entities": [(0, 6,"LOC"),]}),
("মোল্লাহাট", {"entities": [(0, 9,"LOC"),]}),
("মোসাবি", {"entities": [(0, 6,"LOC"),]}),
("মোহনগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("মোহনপুর", {"entities": [(0, 7,"LOC"),]}),
("মোহাম্মদপুর", {"entities": [(0, 11,"LOC"),]}),
("মৌরিতানিয়া", {"entities": [(0, 10,"LOC"),]}),
("মৌরিশাস", {"entities": [(0, 7,"LOC"),]}),
("মৌলভীবাজার", {"entities": [(0, 10,"LOC"),]}),
("ম্যানিলা", {"entities": [(0, 8,"LOC"),]}),
("ময়মনসিংহ", {"entities": [(0, 8,"LOC"),]}),
("যশোর", {"entities": [(0, 4,"LOC"),]}),
("যুক্তরাষ্ট্র", {"entities": [(0, 12,"LOC"),]}),
("রংপুর", {"entities": [(0, 5,"LOC"),]}),
("রাউজান", {"entities": [(0, 6,"LOC"),]}),
("রাঙ্গাবালী", {"entities": [(0, 10,"LOC"),]}),
("রাঙ্গামাটি", {"entities": [(0, 10,"LOC"),]}),
("রাঙ্গুনিয়া", {"entities": [(0, 11,"LOC"),]}),
("রাজধানী", {"entities": [(0, 7,"LOC"),]}),
("রাজনগর", {"entities": [(0, 6,"LOC"),]}),
("রাজবাড়ী", {"entities": [(0, 8,"LOC"),]}),
("রাজবাড়ী", {"entities": [(0, 7,"LOC"),]}),
("রাজশাহী", {"entities": [(0, 7,"LOC"),]}),
("রাজস্থলী", {"entities": [(0, 8,"LOC"),]}),
("রাজাপুর", {"entities": [(0, 7,"LOC"),]}),
("রাজারহাট", {"entities": [(0, 8,"LOC"),]}),
("রাজিবপুর", {"entities": [(0, 8,"LOC"),]}),
("রাজৈর", {"entities": [(0, 5,"LOC"),]}),
("রানীনগর", {"entities": [(0, 7,"LOC"),]}),
("রানীশংকৈল", {"entities": [(0, 9,"LOC"),]}),
("রাবাত", {"entities": [(0, 5,"LOC"),]}),
("রামগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("রামগড়", {"entities": [(0, 6,"LOC"),]}),
("রামগতি", {"entities": [(0, 6,"LOC"),]}),
("রামপাল", {"entities": [(0, 6,"LOC"),]}),
("রামাল্লা", {"entities": [(0, 8,"LOC"),]}),
("রামু", {"entities": [(0, 4,"LOC"),]}),
("রায়গঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("রায়পুর", {"entities": [(0, 7,"LOC"),]}),
("রায়পুরা", {"entities": [(0, 8,"LOC"),]}),
("রাশিয়া", {"entities": [(0, 6,"LOC"),]}),
("রিকজাভিক", {"entities": [(0, 8,"LOC"),]}),
("রিগা", {"entities": [(0, 4,"LOC"),]}),
("রিপাবলিক", {"entities": [(0, 8,"LOC"),]}),
("রিয়াদ", {"entities": [(0, 5,"LOC"),]}),
("রুমা", {"entities": [(0, 4,"LOC"),]}),
("রুমানিয়া", {"entities": [(0, 8,"LOC"),]}),
("রুয়ান্ডা", {"entities": [(0, 8,"LOC"),]}),
("রূপগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("রূপসা", {"entities": [(0, 5,"LOC"),]}),
("রোম", {"entities": [(0, 3,"LOC"),]}),
("রোয়াংছড়ি", {"entities": [(0, 10,"LOC"),]}),
("রোসিয়াউ", {"entities": [(0, 7,"LOC"),]}),
("রৌমারী", {"entities": [(0, 6,"LOC"),]}),
("লংগদু", {"entities": [(0, 5,"LOC"),]}),
("লক্ষীছড়ি", {"entities": [(0, 9,"LOC"),]}),
("লক্ষ্মীপুর", {"entities": [(0, 10,"LOC"),]}),
("লন্ডন", {"entities": [(0, 5,"LOC"),]}),
("লা", {"entities": [(0, 2,"LOC"),]}),
("লাইবেরিয়া", {"entities": [(0, 9,"LOC"),]}),
("লাওস", {"entities": [(0, 4,"LOC"),]}),
("লাকসাম", {"entities": [(0, 6,"LOC"),]}),
("লাখাই", {"entities": [(0, 5,"LOC"),]}),
("লাঙ্গলকোট", {"entities": [(0, 9,"LOC"),]}),
("লাটভিয়া", {"entities": [(0, 7,"LOC"),]}),
("লাপাজ", {"entities": [(0, 5,"LOC"),]}),
("লাভ", {"entities": [(0, 3,"LOC"),]}),
("লামা", {"entities": [(0, 4,"LOC"),]}),
("লালপুর", {"entities": [(0, 6,"LOC"),]}),
("লালমনিরহাট", {"entities": [(0, 10,"LOC"),]}),
("লালমাই", {"entities": [(0, 6,"LOC"),]}),
("লালমোহন", {"entities": [(0, 7,"LOC"),]}),
("লিচেনস্টেইন", {"entities": [(0, 11,"LOC"),]}),
("লিথুনিয়া", {"entities": [(0, 8,"LOC"),]}),
("লিবিয়া", {"entities": [(0, 6,"LOC"),]}),
("লিব্রেভিল", {"entities": [(0, 9,"LOC"),]}),
("লিমা", {"entities": [(0, 4,"LOC"),]}),
("লিলংউই", {"entities": [(0, 6,"LOC"),]}),
("লিসবন", {"entities": [(0, 5,"LOC"),]}),
("লুক্সেমবার্গ", {"entities": [(0, 12,"LOC"),]}),
("লুবজানা", {"entities": [(0, 7,"LOC"),]}),
("লুসাকা", {"entities": [(0, 6,"LOC"),]}),
("লুসিয়া", {"entities": [(0, 6,"LOC"),]}),
("লেবানন", {"entities": [(0, 6,"LOC"),]}),
("লেসোথো", {"entities": [(0, 6,"LOC"),]}),
("লোম", {"entities": [(0, 3,"LOC"),]}),
("লোহাগড়া", {"entities": [(0, 8,"LOC"),]}),
("লোহাগাড়া", {"entities": [(0, 9,"LOC"),]}),
("লৌহজং", {"entities": [(0, 5,"LOC"),]}),
("শরণখোলা", {"entities": [(0, 7,"LOC"),]}),
("শরিয়তপুর", {"entities": [(0, 9,"LOC"),]}),
("শরিয়তপুর", {"entities": [(0, 8,"LOC"),]}),
("শরীয়তপুর", {"entities": [(0, 9,"LOC"),]}),
("শাজাহানপুর", {"entities": [(0, 10,"LOC"),]}),
("শায়েস্তাগঞ্জ", {"entities": [(0, 13,"LOC"),]}),
("শার্শা", {"entities": [(0, 6,"LOC"),]}),
("শালিখা", {"entities": [(0, 6,"LOC"),]}),
("শাল্লা", {"entities": [(0, 6,"LOC"),]}),
("শাহজাদপুর", {"entities": [(0, 9,"LOC"),]}),
("শাহরাস্তি", {"entities": [(0, 9,"LOC"),]}),
("শিবগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("শিবচর", {"entities": [(0, 5,"LOC"),]}),
("শিবপুর", {"entities": [(0, 6,"LOC"),]}),
("শিবালয়", {"entities": [(0, 7,"LOC"),]}),
("শেরপুর", {"entities": [(0, 6,"LOC"),]}),
("শৈলকুপা", {"entities": [(0, 7,"LOC"),]}),
("শ্যামনগর", {"entities": [(0, 8,"LOC"),]}),
("শ্রীনগর", {"entities": [(0, 7,"LOC"),]}),
("শ্রীপুর", {"entities": [(0, 7,"LOC"),]}),
("শ্রীবরদী", {"entities": [(0, 8,"LOC"),]}),
("শ্রীমঙ্গল", {"entities": [(0, 9,"LOC"),]}),
("শ্রীলংকা", {"entities": [(0, 8,"LOC"),]}),
("সখিপুর", {"entities": [(0, 6,"LOC"),]}),
("সদরপুর", {"entities": [(0, 6,"LOC"),]}),
("সন্দ্বীপ", {"entities": [(0, 8,"LOC"),]}),
("সমূহচট্টগ্রাম", {"entities": [(0, 13,"LOC"),]}),
("সমূহঢাকা", {"entities": [(0, 8,"LOC"),]}),
("সমূহবরিশাল", {"entities": [(0, 10,"LOC"),]}),
("সমূহময়মনসিংহ", {"entities": [(0, 13,"LOC"),]}),
("সমূহমৌলভীবাজার", {"entities": [(0, 14,"LOC"),]}),
("সমূহরংপুর", {"entities": [(0, 9,"LOC"),]}),
("সমূহরাজশাহী", {"entities": [(0, 11,"LOC"),]}),
("সরাইল", {"entities": [(0, 5,"LOC"),]}),
("সরিষাবাড়ি", {"entities": [(0, 10,"LOC"),]}),
("সলোমন", {"entities": [(0, 5,"LOC"),]}),
("সাঁথিয়া", {"entities": [(0, 8,"LOC"),]}),
("সাইপ্রাস", {"entities": [(0, 8,"LOC"),]}),
("সাওটোমে", {"entities": [(0, 7,"LOC"),]}),
("সাঘাটা", {"entities": [(0, 6,"LOC"),]}),
("সাটুরিয়া", {"entities": [(0, 9,"LOC"),]}),
("সাতকানিয়া", {"entities": [(0, 10,"LOC"),]}),
("সাতক্ষীরা", {"entities": [(0, 9,"LOC"),]}),
("সাদুল্লাপুর", {"entities": [(0, 11,"LOC"),]}),
("সান", {"entities": [(0, 3,"LOC"),]}),
("সানজুয়ান", {"entities": [(0, 8,"LOC"),]}),
("সানজোসে", {"entities": [(0, 7,"LOC"),]}),
("সানমেরিনো", {"entities": [(0, 9,"LOC"),]}),
("সানা", {"entities": [(0, 4,"LOC"),]}),
("সান্টিয়াগো", {"entities": [(0, 10,"LOC"),]}),
("সাপাহার", {"entities": [(0, 7,"LOC"),]}),
("সাভার", {"entities": [(0, 5,"LOC"),]}),
("সামোয়া", {"entities": [(0, 6,"LOC"),]}),
("সারায়েবো", {"entities": [(0, 8,"LOC"),]}),
("সারিয়াকান্দি", {"entities": [(0, 13,"LOC"),]}),
("সার্বিয়া", {"entities": [(0, 8,"LOC"),]}),
("সালথা", {"entities": [(0, 5,"LOC"),]}),
("সালভাদর", {"entities": [(0, 7,"LOC"),]}),
("সালাম", {"entities": [(0, 5,"LOC"),]}),
("সাহারা", {"entities": [(0, 6,"LOC"),]}),
("সিংড়া", {"entities": [(0, 6,"LOC"),]}),
("সিউল", {"entities": [(0, 4,"LOC"),]}),
("সিঙ্গাইর", {"entities": [(0, 8,"LOC"),]}),
("সিঙ্গাপুর", {"entities": [(0, 9,"LOC"),]}),
("সিটি", {"entities": [(0, 4,"LOC"),]}),
("সিরাজগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("সিরাজদীখান", {"entities": [(0, 10,"LOC"),]}),
("সিরিয়া", {"entities": [(0, 6,"LOC"),]}),
("সিলেট", {"entities": [(0, 5,"LOC"),]}),
("সিসিলি", {"entities": [(0, 6,"LOC"),]}),
("সিয়েরালিওন", {"entities": [(0, 10,"LOC"),]}),
("সীতাকুণ্ড", {"entities": [(0, 9,"LOC"),]}),
("সুইজারল্যান্ড", {"entities": [(0, 13,"LOC"),]}),
("সুইডেন", {"entities": [(0, 6,"LOC"),]}),
("সুজানগর", {"entities": [(0, 7,"LOC"),]}),
("সুদান", {"entities": [(0, 5,"LOC"),]}),
("সুনামগঞ্জ", {"entities": [(0, 9,"LOC"),]}),
("সুন্দরগঞ্জ", {"entities": [(0, 10,"LOC"),]}),
("সুবর্ণ", {"entities": [(0, 6,"LOC"),]}),
("সুভা", {"entities": [(0, 4,"LOC"),]}),
("সুরমা", {"entities": [(0, 5,"LOC"),]}),
("সুরিনাম", {"entities": [(0, 7,"LOC"),]}),
("সেনবাগ", {"entities": [(0, 6,"LOC"),]}),
("সেনেগাল", {"entities": [(0, 7,"LOC"),]}),
("সেন্ট", {"entities": [(0, 5,"LOC"),]}),
("সেন্টকিটস", {"entities": [(0, 9,"LOC"),]}),
("সৌদি", {"entities": [(0, 5,"LOC"),]}),
("সৈয়দপুর", {"entities": [(0, 8,"LOC"),]}),
("সোনাইমুড়ি", {"entities": [(0, 10,"LOC"),]}),
("সোনাগাজী", {"entities": [(0, 8,"LOC"),]}),
("সোনাতলা", {"entities": [(0, 7,"LOC"),]}),
("সোনারগাঁও", {"entities": [(0, 9,"LOC"),]}),
("সোফিয়া", {"entities": [(0, 6,"LOC"),]}),
("সোমালিয়া", {"entities": [(0, 8,"LOC"),]}),
("সোয়াজিল্যান্ড", {"entities": [(0, 13,"LOC"),]}),
("স্কোপজে", {"entities": [(0, 7,"LOC"),]}),
("স্টকহোম", {"entities": [(0, 7,"LOC"),]}),
("স্পেন", {"entities": [(0, 5,"LOC"),]}),
("স্বরূপকাঠি", {"entities": [(0, 10,"LOC"),]}),
("স্লোভাকিয়া", {"entities": [(0, 10,"LOC"),]}),
("স্লোভেনিয়া", {"entities": [(0, 10,"LOC"),]}),
("হন্ডুরাস", {"entities": [(0, 8,"LOC"),]}),
("হবিগঞ্জ", {"entities": [(0, 7,"LOC"),]}),
("হরিণাকুন্ডু", {"entities": [(0, 11,"LOC"),]}),
("হরিপুর", {"entities": [(0, 6,"LOC"),]}),
("হরিরামপুর", {"entities": [(0, 9,"LOC"),]}),
("হাইতি", {"entities": [(0, 5,"LOC"),]}),
("হাইমচর", {"entities": [(0, 6,"LOC"),]}),
("হাকিমপুর", {"entities": [(0, 8,"LOC"),]}),
("হাঙ্গেরী", {"entities": [(0, 8,"LOC"),]}),
("হাজীগঞ্জ", {"entities": [(0, 8,"LOC"),]}),
("হাটহাজারী", {"entities": [(0, 9,"LOC"),]}),
("হাতিয়া", {"entities": [(0, 7,"LOC"),]}),
("হাতিয়ার", {"entities": [(0, 8,"LOC"),]}),
("হাতীবান্ধা", {"entities": [(0, 10,"LOC"),]}),
("হাভানা", {"entities": [(0, 6,"LOC"),]}),
("হারারে", {"entities": [(0, 6,"LOC"),]}),
("হার্জেগোভিনা", {"entities": [(0, 12,"LOC"),]}),
("হালুয়াঘাট", {"entities": [(0, 10,"LOC"),]}),
("হিজলা", {"entities": [(0, 5,"LOC"),]}),
("হেগেন", {"entities": [(0, 5,"LOC"),]}),
("হেলসিংকি", {"entities": [(0, 8,"LOC"),]}),
("হোনিয়ারা", {"entities": [(0, 8,"LOC"),]}),
("হোমনা", {"entities": [(0, 5,"LOC"),]}),
("হোসেনপুর", {"entities": [(0, 8,"LOC"),]}),
("হ্যানয়", {"entities": [(0, 6,"LOC"),]}),
("হ্যামিলটননং", {"entities": [(0, 11,"LOC"),]}),
("উত্তর কোরিয়া", {"entities": [(0, 12,"LOC"),]}),
("উলান বাটর", {"entities": [(0, 9,"LOC"),]}),
("কুয়েত সিটি", {"entities": [(0, 10,"LOC"),]}),
("চাঁপাই নবাবগঞ্জ", {"entities": [(0, 15,"LOC"),]}),
("দক্ষিণ কোরিয়া", {"entities": [(0, 13,"LOC"),]}),
("পূর্ব তিমুর", {"entities": [(0, 11,"LOC"),]}),
("বন্দর সেরী", {"entities": [(0, 10,"LOC"),]}),
("ভিয়েন তিয়েন", {"entities": [(0, 11,"LOC"),]}),
("সংযুক্ত আরব আমিরাত", {"entities": [(0, 18,"LOC"),]}),
("সিঙ্গাপুর সিটি", {"entities": [(0, 14,"LOC"),]}),
("সৌদি আরব", {"entities": [(0, 9,"LOC"),]}),
("অংশ", {"entities": [(0, 3,"NE"),]}),
("অঙ্কে", {"entities": [(0, 5,"NE"),]}),
("অঞ্চল", {"entities": [(0, 5,"NE"),]}),
("অঞ্চলের", {"entities": [(0, 7,"NE"),]}),
("অতিদরিদ্র", {"entities": [(0, 9,"NE"),]}),
("অদ্যাবধি", {"entities": [(0, 8,"NE"),]}),
("অধিবাসীদের", {"entities": [(0, 10,"NE"),]}),
("অধিরাজ্যে", {"entities": [(0, 9,"NE"),]}),
("অন্যতম", {"entities": [(0, 6,"NE"),]}),
("অন্যান্য", {"entities": [(0, 8,"NE"),]}),
("অফ", {"entities": [(0, 2,"NE"),]}),
("অভ্যুত্থান", {"entities": [(0, 10,"NE"),]}),
("অর্জনপূর্বক", {"entities": [(0, 11,"NE"),]}),
("অর্থনীতিক", {"entities": [(0, 9,"NE"),]}),
("অর্থনীতিসমূহের", {"entities": [(0, 14,"NE"),]}),
("অর্থনৈতিক", {"entities": [(0, 9,"NE"),]}),
("অর্থবছরে", {"entities": [(0, 8,"NE"),]}),
("অর্থাৎ", {"entities": [(0, 6,"NE"),]}),
("অষ্টম", {"entities": [(0, 5,"NE"),]}),
("অস্থিতিশীলতা", {"entities": [(0, 12,"NE"),]}),
("আঞ্চলিক", {"entities": [(0, 7,"NE"),]}),
("আন্তর্জাতিক", {"entities": [(0, 11,"NE"),]}),
("আন্দোলন", {"entities": [(0, 7,"NE"),]}),
("আয়", {"entities": [(0, 3,"NE"),]}),
("আয়তনের", {"entities": [(0, 7,"NE"),]}),
("আর্বিভাব", {"entities": [(0, 8,"NE"),]}),
("ইত্যাদি", {"entities": [(0, 7,"NE"),]}),
("উচ্চাকাঙ্ক্ষী", {"entities": [(0, 13,"NE"),]}),
("উদ্যোক্তা", {"entities": [(0, 9,"NE"),]}),
("উন্নতির", {"entities": [(0, 7,"NE"),]}),
("উন্নয়নশীল", {"entities": [(0, 10,"NE"),]}),
("উন্নীত", {"entities": [(0, 6,"NE"),]}),
("উর্বর", {"entities": [(0, 5,"NE"),]}),
("উৎপাদনের", {"entities": [(0, 8,"NE"),]}),
("এ", {"entities": [(0, 1,"NE"),]}),
("এই", {"entities": [(0, 2,"NE"),]}),
("একই", {"entities": [(0, 3,"NE"),]}),
("একটি", {"entities": [(0, 4,"NE"),]}),
("একাদশ", {"entities": [(0, 5,"NE"),]}),
("এছাড়া", {"entities": [(0, 6,"NE"),]}),
("এছাড়াও", {"entities": [(0, 7,"NE"),]}),
("এদেশের", {"entities": [(0, 6,"NE"),]}),
("এবং", {"entities": [(0, 3,"NE"),]}),
("এর", {"entities": [(0, 2,"NE"),]}),
("এশিয়ার", {"entities": [(0, 7,"NE"),]}),
("এশীয়", {"entities": [(0, 5,"NE"),]}),
("ও", {"entities": [(0, 1,"NE"),]}),
("ওআইসি", {"entities": [(0, 5,"NE"),]}),
("ঔপনিবেশিক", {"entities": [(0, 9,"NE"),]}),
("ক", {"entities": [(0, 1,"NE"),]}),
("কম", {"entities": [(0, 2,"NE"),]}),
("কমনওয়েলথ", {"entities": [(0, 9,"NE"),]}),
("করছে", {"entities": [(0, 4,"NE"),]}),
("করা", {"entities": [(0, 3,"NE"),]}),
("করে", {"entities": [(0, 3,"NE"),]}),
("করেছে", {"entities": [(0, 5,"NE"),]}),
("কাজ", {"entities": [(0, 3,"NE"),]}),
("কেন্দ্রবিন্দুতে", {"entities": [(0, 15,"NE"),]}),
("কোটি", {"entities": [(0, 4,"NE"),]}),
("কোটির", {"entities": [(0, 5,"NE"),]}),
("ক্ষুদ্রায়তন", {"entities": [(0, 12,"NE"),]}),
("খ্রিস্টাব্দে", {"entities": [(0, 12,"NE"),]}),
("গণতান্ত্রিক", {"entities": [(0, 11,"NE"),]}),
("গণপ্রজাতন্ত্রী", {"entities": [(0, 14,"NE"),]}),
("গণসংগ্রামের", {"entities": [(0, 11,"NE"),]}),
("গত", {"entities": [(0, 2,"NE"),]}),
("ঘটেছে", {"entities": [(0, 5,"NE"),]}),
("ঘনবসতিপূর্ণ", {"entities": [(0, 11,"NE"),]}),
("চলতি", {"entities": [(0, 4,"NE"),]}),
("চালিকাশক্তিরূপে", {"entities": [(0, 15,"NE"),]}),
("ছিল", {"entities": [(0, 3,"NE"),]}),
("জন", {"entities": [(0, 2,"NE"),]}),
("জনগণের", {"entities": [(0, 6,"NE"),]}),
("জনবসতি", {"entities": [(0, 6,"NE"),]}),
("জনবহুল", {"entities": [(0, 6,"NE"),]}),
("জনশক্তি", {"entities": [(0, 7,"NE"),]}),
("জনসংখ্যা", {"entities": [(0, 8,"NE"),]}),
("জনসংখ্যার", {"entities": [(0, 9,"NE"),]}),
("জাতি", {"entities": [(0, 4,"NE"),]}),
("জাতিরাষ্ট্র", {"entities": [(0, 11,"NE"),]}),
("জাতিসংঘ", {"entities": [(0, 7,"NE"),]}),
("জিডিপি", {"entities": [(0, 6,"NE"),]}),
("জোট", {"entities": [(0, 3,"NE"),]}),
("টাকা", {"entities": [(0, 4,"NE"),]}),
("টাকায়", {"entities": [(0, 6,"NE"),]}),
("টাকার", {"entities": [(0, 5,"NE"),]}),
("টি", {"entities": [(0, 2,"NE"),]}),
("ডলার", {"entities": [(0, 4,"NE"),]}),
("ডলারে", {"entities": [(0, 5,"NE"),]}),
("তখন", {"entities": [(0, 3,"NE"),]}),
("তম", {"entities": [(0, 2,"NE"),]}),
("তার", {"entities": [(0, 3,"NE"),]}),
("তালিকায়", {"entities": [(0, 8,"NE"),]}),
("তৈরি", {"entities": [(0, 4,"NE"),]}),
("ত্বরিৎ", {"entities": [(0, 6,"NE"),]}),
("ত্রিপুরায়", {"entities": [(0, 10,"NE"),]}),
("থাকাকালীন", {"entities": [(0, 9,"NE"),]}),
("থেকে", {"entities": [(0, 4,"NE"),]}),
("দশক", {"entities": [(0, 3,"NE"),]}),
("দশকে", {"entities": [(0, 4,"NE"),]}),
("দারিদ্র", {"entities": [(0, 7,"NE"),]}),
("দারিদ্রের", {"entities": [(0, 9,"NE"),]}),
("দারিদ্র্যপীড়িত", {"entities": [(0, 15,"NE"),]}),
("দিকে", {"entities": [(0, 4,"NE"),]}),
("দিয়ে", {"entities": [(0, 5,"NE"),]}),
("দীর্ঘ", {"entities": [(0, 5,"NE"),]}),
("দুই", {"entities": [(0, 3,"NE"),]}),
("দুর্ভিক্ষ", {"entities": [(0, 9,"NE"),]}),
("দুর্যোগ", {"entities": [(0, 7,"NE"),]}),
("দেশ", {"entities": [(0, 3,"NE"),]}),
("দেশগুলোর", {"entities": [(0, 8,"NE"),]}),
("দেশজ", {"entities": [(0, 4,"NE"),]}),
("দেশটি", {"entities": [(0, 5,"NE"),]}),
("দেশটির", {"entities": [(0, 6,"NE"),]}),
("ধরে", {"entities": [(0, 3,"NE"),]}),
("ধারাবাহিকতা", {"entities": [(0, 11,"NE"),]}),
("নবগঠিত", {"entities": [(0, 6,"NE"),]}),
("নবম", {"entities": [(0, 3,"NE"),]}),
("নিপীড়নের", {"entities": [(0, 9,"NE"),]}),
("নিয়েছে", {"entities": [(0, 7,"NE"),]}),
("নিরপেক্ষ", {"entities": [(0, 8,"NE"),]}),
("নেশনস", {"entities": [(0, 5,"NE"),]}),
("পরবর্তী", {"entities": [(0, 7,"NE"),]}),
("পরিচিত", {"entities": [(0, 6,"NE"),]}),
("পরিবর্তিত", {"entities": [(0, 9,"NE"),]}),
("পরিবর্ধন", {"entities": [(0, 8,"NE"),]}),
("পরিমাণ", {"entities": [(0, 6,"NE"),]}),
("পরে", {"entities": [(0, 3,"NE"),]}),
("পায়", {"entities": [(0, 4,"NE"),]}),
("পার্শ্ববর্তী", {"entities": [(0, 12,"NE"),]}),
("পুনঃপৌনিক", {"entities": [(0, 9,"NE"),]}),
("পুনঃপ্রতিষ্ঠিত", {"entities": [(0, 14,"NE"),]}),
("পূর্ব", {"entities": [(0, 5,"NE"),]}),
("পূর্ববর্তী", {"entities": [(0, 10,"NE"),]}),
("পূর্বাংশের", {"entities": [(0, 10,"NE"),]}),
("পৃথিবীতে", {"entities": [(0, 8,"NE"),]}),
("পেয়ে", {"entities": [(0, 5,"NE"),]}),
("পোশাক", {"entities": [(0, 5,"NE"),]}),
("প্রগতি", {"entities": [(0, 6,"NE"),]}),
("প্রচলিত", {"entities": [(0, 7,"NE"),]}),
("প্রতি", {"entities": [(0, 5,"NE"),]}),
("প্রতিকূলতা", {"entities": [(0, 10,"NE"),]}),
("প্রতিষ্ঠাতা", {"entities": [(0, 11,"NE"),]}),
("প্রতিষ্ঠিত", {"entities": [(0, 10,"NE"),]}),
("প্রবৃদ্ধির", {"entities": [(0, 10,"NE"),]}),
("প্রলম্বিত", {"entities": [(0, 9,"NE"),]}),
("প্রসিদ্ধ", {"entities": [(0, 8,"NE"),]}),
("প্রাকৃতিক", {"entities": [(0, 9,"NE"),]}),
("প্রাক্কলন", {"entities": [(0, 9,"NE"),]}),
("প্রাচীন", {"entities": [(0, 7,"NE"),]}),
("প্রায়", {"entities": [(0, 6,"NE"),]}),
("প্রেসিডেন্সি", {"entities": [(0, 12,"NE"),]}),
("ফলে", {"entities": [(0, 3,"NE"),]}),
("বঙ্গ", {"entities": [(0, 4,"NE"),]}),
("বঙ্গোপসাগর", {"entities": [(0, 10,"NE"),]}),
("বদ্বীপের", {"entities": [(0, 8,"NE"),]}),
("বর্গমাইলে", {"entities": [(0, 9,"NE"),]}),
("বর্গমাইলেরও", {"entities": [(0, 11,"NE"),]}),
("বর্তমান", {"entities": [(0, 7,"NE"),]}),
("বর্তমানে", {"entities": [(0, 8,"NE"),]}),
("বাংলা", {"entities": [(0, 5,"NE"),]}),
("বাঙালি", {"entities": [(0, 6,"NE"),]}),
("বাজারমূল্যে", {"entities": [(0, 11,"NE"),]}),
("বাণিজ্য", {"entities": [(0, 7,"NE"),]}),
("বারংবার", {"entities": [(0, 7,"NE"),]}),
("বার্ষিক", {"entities": [(0, 7,"NE"),]}),
("বাস", {"entities": [(0, 3,"NE"),]}),
("বিকাশ", {"entities": [(0, 5,"NE"),]}),
("বিভাগ", {"entities": [(0, 5,"NE"),]}),
("বিভিন্ন", {"entities": [(0, 7,"NE"),]}),
("বিমসটেক", {"entities": [(0, 7,"NE"),]}),
("বিশেষ", {"entities": [(0, 5,"NE"),]}),
("বিশেষভাবে", {"entities": [(0, 9,"NE"),]}),
("বিশ্ব", {"entities": [(0, 5,"NE"),]}),
("বিশ্বে", {"entities": [(0, 6,"NE"),]}),
("বিশ্বের", {"entities": [(0, 7,"NE"),]}),
("বৃদ্ধি", {"entities": [(0, 6,"NE"),]}),
("বেঙ্গল", {"entities": [(0, 6,"NE"),]}),
("বেশী", {"entities": [(0, 4,"NE"),]}),
("বৈষম্য", {"entities": [(0, 6,"NE"),]}),
("ব্যবস্থা", {"entities": [(0, 8,"NE"),]}),
("ব্যাহত", {"entities": [(0, 6,"NE"),]}),
("ব্রিটিশ", {"entities": [(0, 7,"NE"),]}),
("বৎসরের", {"entities": [(0, 6,"NE"),]}),
("ভাষা", {"entities": [(0, 4,"NE"),]}),
("ভূখন্ড", {"entities": [(0, 6,"NE"),]}),
("ভূখন্ডের", {"entities": [(0, 8,"NE"),]}),
("ভৌগলিকভাবে", {"entities": [(0, 10,"NE"),]}),
("মর্মে", {"entities": [(0, 5,"NE"),]}),
("মর্যাদা", {"entities": [(0, 7,"NE"),]}),
("মাতৃভাষা", {"entities": [(0, 8,"NE"),]}),
("মাত্র", {"entities": [(0, 5,"NE"),]}),
("মাথাপিছু", {"entities": [(0, 8,"NE"),]}),
("মানুষের", {"entities": [(0, 7,"NE"),]}),
("মায়ানমার", {"entities": [(0, 9,"NE"),]}),
("মার্কিন", {"entities": [(0, 7,"NE"),]}),
("মোট", {"entities": [(0, 3,"NE"),]}),
("যখন", {"entities": [(0, 3,"NE"),]}),
("যদিও", {"entities": [(0, 4,"NE"),]}),
("যা", {"entities": [(0, 2,"NE"),]}),
("যাবৎ", {"entities": [(0, 4,"NE"),]}),
("যার", {"entities": [(0, 3,"NE"),]}),
("যে", {"entities": [(0, 2,"NE"),]}),
("যেটি", {"entities": [(0, 4,"NE"),]}),
("রপ্তানীও", {"entities": [(0, 8,"NE"),]}),
("রপ্তানীমুখী", {"entities": [(0, 11,"NE"),]}),
("রাজনৈতিক", {"entities": [(0, 8,"NE"),]}),
("রাজ্য", {"entities": [(0, 5,"NE"),]}),
("রাষ্ট্র", {"entities": [(0, 7,"NE"),]}),
("শতাংশ", {"entities": [(0, 5,"NE"),]}),
("শহরের", {"entities": [(0, 5,"NE"),]}),
("শাসনব্যবস্থা", {"entities": [(0, 12,"NE"),]}),
("শাসনাবসানে", {"entities": [(0, 10,"NE"),]}),
("শিক্ষার", {"entities": [(0, 7,"NE"),]}),
("শিল্প", {"entities": [(0, 5,"NE"),]}),
("শুল্ক", {"entities": [(0, 5,"NE"),]}),
("শোষণ", {"entities": [(0, 4,"NE"),]}),
("শ্রেণীর", {"entities": [(0, 7,"NE"),]}),
("সংখ্যা", {"entities": [(0, 6,"NE"),]}),
("সংখ্যাগরিষ্ট", {"entities": [(0, 12,"NE"),]}),
("সংগ্রামের", {"entities": [(0, 9,"NE"),]}),
("সংঘের", {"entities": [(0, 5,"NE"),]}),
("সংসদীয়", {"entities": [(0, 7,"NE"),]}),
("সংস্থা", {"entities": [(0, 6,"NE"),]}),
("সকল", {"entities": [(0, 3,"NE"),]}),
("সক্রিয়", {"entities": [(0, 7,"NE"),]}),
("সক্ষম", {"entities": [(0, 5,"NE"),]}),
("সঙ্গে", {"entities": [(0, 5,"NE"),]}),
("সত্বেও", {"entities": [(0, 6,"NE"),]}),
("সদস্য", {"entities": [(0, 5,"NE"),]}),
("সবচেয়ে", {"entities": [(0, 7,"NE"),]}),
("সময়", {"entities": [(0, 4,"NE"),]}),
("সময়ে", {"entities": [(0, 5,"NE"),]}),
("সমৃদ্ধি", {"entities": [(0, 7,"NE"),]}),
("সরকার", {"entities": [(0, 5,"NE"),]}),
("সরকারী", {"entities": [(0, 6,"NE"),]}),
("সশস্ত্র", {"entities": [(0, 7,"NE"),]}),
("সহযোগিতা", {"entities": [(0, 8,"NE"),]}),
("সাংবিধানিক", {"entities": [(0, 10,"NE"),]}),
("সামগ্রিক", {"entities": [(0, 8,"NE"),]}),
("সামরিক", {"entities": [(0, 6,"NE"),]}),
("সারা", {"entities": [(0, 4,"NE"),]}),
("সার্বভৌম", {"entities": [(0, 8,"NE"),]}),
("সীমান্ত", {"entities": [(0, 7,"NE"),]}),
("সীমান্তে", {"entities": [(0, 8,"NE"),]}),
("স্থান", {"entities": [(0, 5,"NE"),]}),
("স্থিতিশীলতা", {"entities": [(0, 11,"NE"),]}),
("স্বাধীন", {"entities": [(0, 7,"NE"),]}),
("স্বাধীনতা", {"entities": [(0, 9,"NE"),]}),
("স্বীকৃতি", {"entities": [(0, 8,"NE"),]}),
("হয়", {"entities": [(0, 3,"NE"),]}),
("হয়েছিল", {"entities": [(0, 7,"NE"),]}),
("হয়েছে", {"entities": [(0, 6,"NE"),]}),
("হাজার", {"entities": [(0, 5,"NE"),]}),
("হার", {"entities": [(0, 3,"NE"),]}),
("হারে", {"entities": [(0, 4,"NE"),]}),
("হিসাবে", {"entities": [(0, 6,"NE"),]}),
("হিসেবে", {"entities": [(0, 6,"NE"),]}),
("হ্রাসের", {"entities": [(0, 7,"NE"),]}),]

# %%
len(TRAIN_DATA)
# Out:
# 1218

# %%
#!/usr/bin/env python
# coding: utf8
"""Example of training spaCy's named entity recognizer, starting off with an
existing model or a blank model.
For more details, see the documentation:
* Training: https://spacy.io/usage/training
* NER: https://spacy.io/usage/linguistic-features#named-entities
Compatible with: spaCy v2.0.0+
Last tested with: v2.2.4
"""
from __future__ import unicode_literals, print_function
import plac
import random
import warnings
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding
#import en_trf_robertabase_lg
#from spacy.en import English
#from spacy.lang.en import English
# training data
#TRAIN_DATA = TRAIN_DATA
#TRAIN_DATA=[("প্রাণ নামেই প্রাণ অথচ এটি এখন প্রাণঘাতি পানীয়।", {"entities": [(0,5,"ORG")]}),("প্রাণ নামেই প্রাণ অথচ এটি এখন প্রাণঘাতি পানীয়।", {"entities": [(2,5,"ORG")]})]
@plac.annotations(
    model=("Model name. Defaults to blank 'bn' model.", "option", "m", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_iter=("Number of training iterations", "option", "n", int),
)
def main1(model, output_dir, n_iter):
    
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        print("Loaded model '%s'" % model)
        nlp =en_trf_robertabase_lg.load()  # load existing spaCy model
        print(nlp.pipe_names)
        
    else:
        nlp = spacy.blank("bn")  # create blank Language class
        print("Created blank 'bn' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")
    print(nlp.pipe_names)
    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    
    # get names of other pipes to disable them during training
    pipe_exceptions = ["ner","tagger", "trf_wordpiecer", "trf_tok2vec"]
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
    # only train NER
    with nlp.disable_pipes(*other_pipes) and warnings.catch_warnings():
        # show warnings for misaligned entity spans once
        warnings.filterwarnings("once", category=UserWarning, module='spacy')
        
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        #if model is None:
        nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                #print("oj")
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print('i-> ',itn,' ',"Losses", losses)

    # test the trained model
    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    output_dir='/content/drive/My Drive/ner/'
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        for text, _ in TRAIN_DATA:
            doc = nlp2(text)
            print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
            print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

main1(None,None,1000)

#if __name__ == "__main__":
    #plac.call(main)
    # Expected output:
    # Entities [('Shaka Khan', 'PERSON')]
    # Tokens [('Who', '', 2), ('is', '', 2), ('Shaka', 'PERSON', 3),
    # ('Khan', 'PERSON', 1), ('?', '', 2)]
    # Entities [('London', 'LOC'), ('Berlin', 'LOC')]
    # Tokens [('I', '', 2), ('like', '', 2), ('London', 'LOC', 3),
    # ('and', '', 2), ('Berlin', 'LOC', 3), ('.', '', 2)]

# %%
output_dir='/content/drive/My Drive/ner/'
nlp2 = spacy.load(output_dir)
doc = nlp2("এবং চীন")
for ent in doc.ents:
  print(ent.label_, ent.text)
# Out:
# LOC এবং চীন
